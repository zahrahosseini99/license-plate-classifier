# %% [markdown]
# <h1>Computer Vision: Number Plate Recognition (DPR)</h1>
#
# Number Plate Recognition is an image-processing technology used to identify vehicles by their license plates. This technology is used in various security and traffic applications such as:
# *   **Average-Speed Cameras:** DPR is used for speed limit enforcement. This works by tracking vehicles' travel time between two fixed points, and calculating the average speed.
#
# *   **Crime Deterrent:** Recent innovations have contributed to the adoption of DPR for perimeter security and access control applications at government facilities.
#
# *   **Traffic Control:** Many cities and districts have developed traffic control systems to help monitor the movement and flow of vehicles around the road network.
#
# These are just some of the DPR usage, for more information please visit [Automatic number-plate recognition](https://en.wikipedia.org/wiki/Automatic_number-plate_recognition#Usage) on Wikipedia.
#
#
# In this simpler task, we will classify three classes of normal number plate, defaced number plate and no number plate images. Also we use [Number Plate Recognition Contest](http://aaic.aut.ac.ir/leagues/sc/dpr)'s dataset which was held in [Amirkabir University of Technology](https://aut.ac.ir/en). This [dataset](https://drive.iust.ac.ir/index.php/s/IQOJTSRi6ToITIA) has three subdirectories which is briefly described as follow:
# *   **0:** In this subdirectory, there are 1876 images of normal number plates, which have been taken with different size in different lighting. It should be noted that these number plates are available at different angles and are not necessarily located in the middle of the image.
#
# *   **1:** In this subdirectory, there are 283 images of defaced number plates. The size of these images is different from each other like the previous class. In this class of images, part of the number plate (can be part of numbers or part of letters) is defaced by an object.
#
# *   **2:** In this subdirectory, there are 568 images of no number plates class. Although no number plates can be found in these images, there may be part of the front of the car or text on a sign in the images.
#
# In this task, we use 2183 of above dataset's image as train data and 544 of them as validation data.

# %% [markdown]
# ## 1 - Importing Packages ##
#
# First, let's run the cell below to import all the packages.
# - [cv2](https://opencv.org/) is a library of programming functions mainly aimed at real-time computer vision.
# - [imutils](https://pypi.org/project/imutils/) is a series of convenience functions to make basic image processing functions much more easier with OpenCV.
# - [numpy](www.numpy.org) is the fundamental package for scientific computing with Python.
# - [matplotlib](http://matplotlib.org) is a famous library to plot graphs in Python.
# - [os](https://docs.python.org/3/library/os.html) module in python provides functions for interacting with the operating system.
# - [keras](https://keras.io/) is an open-source neural-network library written in Python.
# - [tensorflow](https://www.tensorflow.org/) is a Python library for fast numerical computing created and released by Google.

# %%
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
import os

from keras.applications import InceptionResNetV2
from keras.applications.inception_resnet_v2 import preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model
from keras.models import load_model
from keras.layers import GlobalAveragePooling2D, Dense
from keras.callbacks import EarlyStopping

import tensorflow_addons as tfa
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ## 2 - Declaring Constants and Parameters ##
#
# Image Parameters:
# - **IMG_WIDTH:** The width of resized dataset's image.
# - **IMG_HEIGHT:** The height of resized dataset's image.
#
# Model parameters:
# - **EPOCHS:** Number of epochs we want to train our model for.
#
# General Parameters:
# - **N_CLASSES:** The number of classes used in dataset.

# %%
# Image Parameters:
IMG_WIDTH, IMG_HEIGHT = 620, 480

# Model Parameters:
EPOCHS = 10
BATCH_SIZE= 10

# Pre-Process Parameters:
STRUCTURING_ELEMENT_1 = cv2.getStructuringElement(cv2.MORPH_RECT, (1, 20))
STRUCTURING_ELEMENT_2 = cv2.getStructuringElement(cv2.MORPH_RECT, (60, 1))
STRUCTURING_ELEMENT_3 = cv2.getStructuringElement(cv2.MORPH_RECT, (20, 1))
STRUCTURING_ELEMENT_4 = cv2.getStructuringElement(cv2.MORPH_RECT, (30, 30))
STRUCTURING_ELEMENT_5 = cv2.getStructuringElement(cv2.MORPH_RECT, (150, 5))

# General Parameters:
N_CLASSES = 3

# %% [markdown]
# ## 3 - Loading Data ##
#
# I provide data from my drive which I uploaded before.
# *   [Dataset.zip](https://drive.google.com/drive/folders/1x6_PuUoB5LQ07IJk_BTSVugbMAeLn6u5?usp=sharing)
# *   [Dataset](https://drive.google.com/file/d/1jBWSOLNo-dwIRjuBj7AcyJWJQHVbFP0M/view?usp=sharing)
#
# Also you can download these datasets from links above.

# %%
# Download Dataset.zip from drive.
# !gdown --id "1jBWSOLNo-dwIRjuBj7AcyJWJQHVbFP0M"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jBWSOLNo-dwIRjuBj7AcyJWJQHVbFP0M
# To: /content/Dataset.zip
# 63.3MB [00:00, 69.1MB/s]

# %%
# Unzip Dataset.zip.
# !unzip Dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Dataset/0/0926.jpg
#   inflating: __MACOSX/Dataset/0/._0926.jpg
#   inflating: Dataset/0/1437.jpg
#   inflating: __MACOSX/Dataset/0/._1437.jpg
#   inflating: Dataset/0/0729.jpg
#   inflating: __MACOSX/Dataset/0/._0729.jpg
#   inflating: Dataset/0/1351.jpg
#   inflating: __MACOSX/Dataset/0/._1351.jpg
#   inflating: Dataset/0/1345.jpg
#   inflating: __MACOSX/Dataset/0/._1345.jpg
#   inflating: Dataset/0/1423.jpg
#   inflating: __MACOSX/Dataset/0/._1423.jpg
#   inflating: Dataset/0/0715.jpg
#   inflating: __MACOSX/Dataset/0/._0715.jpg
#   inflating: Dataset/0/0073.jpg
#   inflating: __MACOSX/Dataset/0/._0073.jpg
#   inflating: Dataset/0/0067.jpg
#   inflating: __MACOSX/Dataset/0/._0067.jpg
#   inflating: Dataset/0/1379.jpg
#   inflating: __MACOSX/Dataset/0/._1379.jpg
#   inflating: Dataset/0/0701.jpg
#   inflating: __MACOSX/Dataset/0/._0701.jpg
#   inflating: Dataset/0/0739.jpg
#   inflating: __MACOSX/Dataset/0/._0739.jpg
#   inflating: Dataset/0/1427.jpg
#   inflating: __MACOSX/Dataset/0/._1427.jpg
#   inflating: Dataset/0/1341.jpg
#   inflating: __MACOSX/Dataset/0/._1341.jpg
#   inflating: Dataset/0/1355.jpg
#   inflating: __MACOSX/Dataset/0/._1355.jpg
#   inflating: Dataset/0/1433.jpg
#   inflating: __MACOSX/Dataset/0/._1433.jpg
#   inflating: Dataset/0/0705.jpg
#   inflating: __MACOSX/Dataset/0/._0705.jpg
#   inflating: Dataset/0/0063.jpg
#   inflating: __MACOSX/Dataset/0/._0063.jpg
#   inflating: Dataset/0/1369.jpg
#   inflating: __MACOSX/Dataset/0/._1369.jpg
#   inflating: Dataset/0/0077.jpg
#   inflating: __MACOSX/Dataset/0/._0077.jpg
#   inflating: Dataset/0/0711.jpg
#   inflating: __MACOSX/Dataset/0/._0711.jpg
#   inflating: Dataset/0/0922.jpg
#   inflating: __MACOSX/Dataset/0/._0922.jpg
#   inflating: Dataset/0/1382.jpg
#   inflating: __MACOSX/Dataset/0/._1382.jpg
#   inflating: Dataset/0/0088.jpg
#   inflating: __MACOSX/Dataset/0/._0088.jpg
#   inflating: Dataset/0/1396.jpg
#   inflating: __MACOSX/Dataset/0/._1396.jpg
#   inflating: Dataset/0/0936.jpg
#   inflating: __MACOSX/Dataset/0/._0936.jpg
#   inflating: Dataset/0/1143.jpg
#   inflating: __MACOSX/Dataset/0/._1143.jpg
#   inflating: Dataset/0/1625.jpg
#   inflating: __MACOSX/Dataset/0/._1625.jpg
#   inflating: Dataset/0/1631.jpg
#   inflating: __MACOSX/Dataset/0/._1631.jpg
#   inflating: Dataset/0/0249.jpg
#   inflating: __MACOSX/Dataset/0/._0249.jpg
#   inflating: Dataset/0/1157.jpg
#   inflating: __MACOSX/Dataset/0/._1157.jpg
#   inflating: Dataset/0/0261.jpg
#   inflating: __MACOSX/Dataset/0/._0261.jpg
#   inflating: Dataset/0/1619.jpg
#   inflating: __MACOSX/Dataset/0/._1619.jpg
#   inflating: Dataset/0/0507.jpg
#   inflating: __MACOSX/Dataset/0/._0507.jpg
#   inflating: Dataset/0/0513.jpg
#   inflating: __MACOSX/Dataset/0/._0513.jpg
#   inflating: Dataset/0/0275.jpg
#   inflating: __MACOSX/Dataset/0/._0275.jpg
#   inflating: Dataset/0/1180.jpg
#   inflating: __MACOSX/Dataset/0/._1180.jpg
#   inflating: Dataset/0/1194.jpg
#   inflating: __MACOSX/Dataset/0/._1194.jpg
#   inflating: Dataset/0/1802.jpg
#   inflating: __MACOSX/Dataset/0/._1802.jpg
#   inflating: Dataset/0/1816.jpg
#   inflating: __MACOSX/Dataset/0/._1816.jpg
#   inflating: Dataset/0/1037.jpg
#   inflating: __MACOSX/Dataset/0/._1037.jpg
#   inflating: Dataset/0/0329.jpg
#   inflating: __MACOSX/Dataset/0/._0329.jpg
#   inflating: Dataset/0/1751.jpg
#   inflating: __MACOSX/Dataset/0/._1751.jpg
#   inflating: Dataset/0/1745.jpg
#   inflating: __MACOSX/Dataset/0/._1745.jpg
#   inflating: Dataset/0/1023.jpg
#   inflating: __MACOSX/Dataset/0/._1023.jpg
#   inflating: Dataset/0/0315.jpg
#   inflating: __MACOSX/Dataset/0/._0315.jpg
#   inflating: Dataset/0/0473.jpg
#   inflating: __MACOSX/Dataset/0/._0473.jpg
#   inflating: Dataset/0/0467.jpg
#   inflating: __MACOSX/Dataset/0/._0467.jpg
#   inflating: Dataset/0/1779.jpg
#   inflating: __MACOSX/Dataset/0/._1779.jpg
#   inflating: Dataset/0/0301.jpg
#   inflating: __MACOSX/Dataset/0/._0301.jpg
#   inflating: Dataset/0/1792.jpg
#   inflating: __MACOSX/Dataset/0/._1792.jpg
#   inflating: Dataset/0/1786.jpg
#   inflating: __MACOSX/Dataset/0/._1786.jpg
#   inflating: Dataset/0/0498.jpg
#   inflating: __MACOSX/Dataset/0/._0498.jpg
#   inflating: Dataset/0/1553.jpg
#   inflating: __MACOSX/Dataset/0/._1553.jpg
#   inflating: Dataset/0/0895.jpg
#   inflating: __MACOSX/Dataset/0/._0895.jpg
#   inflating: Dataset/0/1235.jpg
#   inflating: __MACOSX/Dataset/0/._1235.jpg
#   inflating: Dataset/0/1221.jpg
#   inflating: __MACOSX/Dataset/0/._1221.jpg
#   inflating: Dataset/0/1547.jpg
#   inflating: __MACOSX/Dataset/0/._1547.jpg
#   inflating: Dataset/0/0881.jpg
#   inflating: __MACOSX/Dataset/0/._0881.jpg
#   inflating: Dataset/0/0659.jpg
#   inflating: __MACOSX/Dataset/0/._0659.jpg
#   inflating: Dataset/0/0671.jpg
#   inflating: __MACOSX/Dataset/0/._0671.jpg
#   inflating: Dataset/0/0117.jpg
#   inflating: __MACOSX/Dataset/0/._0117.jpg
#   inflating: Dataset/0/1209.jpg
#   inflating: __MACOSX/Dataset/0/._1209.jpg
#   inflating: Dataset/0/0103.jpg
#   inflating: __MACOSX/Dataset/0/._0103.jpg
#   inflating: Dataset/0/0665.jpg
#   inflating: __MACOSX/Dataset/0/._0665.jpg
#   inflating: Dataset/0/1590.jpg
#   inflating: __MACOSX/Dataset/0/._1590.jpg
#   inflating: Dataset/0/0856.jpg
#   inflating: __MACOSX/Dataset/0/._0856.jpg
#   inflating: Dataset/0/1584.jpg
#   inflating: __MACOSX/Dataset/0/._1584.jpg
#   inflating: Dataset/0/0842.jpg
#   inflating: __MACOSX/Dataset/0/._0842.jpg
#   inflating: Dataset/0/0843.jpg
#   inflating: __MACOSX/Dataset/0/._0843.jpg
#   inflating: Dataset/0/1585.jpg
#   inflating: __MACOSX/Dataset/0/._1585.jpg
#   inflating: Dataset/0/0857.jpg
#   inflating: __MACOSX/Dataset/0/._0857.jpg
#   inflating: Dataset/0/1591.jpg
#   inflating: __MACOSX/Dataset/0/._1591.jpg
#   inflating: Dataset/0/0102.jpg
#   inflating: __MACOSX/Dataset/0/._0102.jpg
#   inflating: Dataset/0/0664.jpg
#   inflating: __MACOSX/Dataset/0/._0664.jpg
#   inflating: Dataset/0/0670.jpg
#   inflating: __MACOSX/Dataset/0/._0670.jpg
#   inflating: Dataset/0/1208.jpg
#   inflating: __MACOSX/Dataset/0/._1208.jpg
#   inflating: Dataset/0/0116.jpg
#   inflating: __MACOSX/Dataset/0/._0116.jpg
#   inflating: Dataset/0/1220.jpg
#   inflating: __MACOSX/Dataset/0/._1220.jpg
#   inflating: Dataset/0/0658.jpg
#   inflating: __MACOSX/Dataset/0/._0658.jpg
#   inflating: Dataset/0/0880.jpg
#   inflating: __MACOSX/Dataset/0/._0880.jpg
#   inflating: Dataset/0/1546.jpg
#   inflating: __MACOSX/Dataset/0/._1546.jpg
#   inflating: Dataset/0/0894.jpg
#   inflating: __MACOSX/Dataset/0/._0894.jpg
#   inflating: Dataset/0/1552.jpg
#   inflating: __MACOSX/Dataset/0/._1552.jpg
#   inflating: Dataset/0/1234.jpg
#   inflating: __MACOSX/Dataset/0/._1234.jpg
#   inflating: Dataset/0/0499.jpg
#   inflating: __MACOSX/Dataset/0/._0499.jpg
#   inflating: Dataset/0/1787.jpg
#   inflating: __MACOSX/Dataset/0/._1787.jpg
#   inflating: Dataset/0/1793.jpg
#   inflating: __MACOSX/Dataset/0/._1793.jpg
#   inflating: Dataset/0/1778.jpg
#   inflating: __MACOSX/Dataset/0/._1778.jpg
#   inflating: Dataset/0/0466.jpg
#   inflating: __MACOSX/Dataset/0/._0466.jpg
#   inflating: Dataset/0/0300.jpg
#   inflating: __MACOSX/Dataset/0/._0300.jpg
#   inflating: Dataset/0/0314.jpg
#   inflating: __MACOSX/Dataset/0/._0314.jpg
#   inflating: Dataset/0/0472.jpg
#   inflating: __MACOSX/Dataset/0/._0472.jpg
#   inflating: Dataset/0/1744.jpg
#   inflating: __MACOSX/Dataset/0/._1744.jpg
#   inflating: Dataset/0/1022.jpg
#   inflating: __MACOSX/Dataset/0/._1022.jpg
#   inflating: Dataset/0/0328.jpg
#   inflating: __MACOSX/Dataset/0/._0328.jpg
#   inflating: Dataset/0/1036.jpg
#   inflating: __MACOSX/Dataset/0/._1036.jpg
#   inflating: Dataset/0/1750.jpg
#   inflating: __MACOSX/Dataset/0/._1750.jpg
#   inflating: Dataset/0/1817.jpg
#   inflating: __MACOSX/Dataset/0/._1817.jpg
#   inflating: Dataset/0/1803.jpg
#   inflating: __MACOSX/Dataset/0/._1803.jpg
#   inflating: Dataset/0/1195.jpg
#   inflating: __MACOSX/Dataset/0/._1195.jpg
#   inflating: Dataset/0/1181.jpg
#   inflating: __MACOSX/Dataset/0/._1181.jpg
#   inflating: Dataset/0/0512.jpg
#   inflating: __MACOSX/Dataset/0/._0512.jpg
#   inflating: Dataset/0/0274.jpg
#   inflating: __MACOSX/Dataset/0/._0274.jpg
#   inflating: Dataset/0/0260.jpg
#   inflating: __MACOSX/Dataset/0/._0260.jpg
#   inflating: Dataset/0/0506.jpg
#   inflating: __MACOSX/Dataset/0/._0506.jpg
#   inflating: Dataset/0/1618.jpg
#   inflating: __MACOSX/Dataset/0/._1618.jpg
#   inflating: Dataset/0/1630.jpg
#   inflating: __MACOSX/Dataset/0/._1630.jpg
#   inflating: Dataset/0/1156.jpg
#   inflating: __MACOSX/Dataset/0/._1156.jpg
#   inflating: Dataset/0/0248.jpg
#   inflating: __MACOSX/Dataset/0/._0248.jpg
#   inflating: Dataset/0/1142.jpg
#   inflating: __MACOSX/Dataset/0/._1142.jpg
#   inflating: Dataset/0/1624.jpg
#   inflating: __MACOSX/Dataset/0/._1624.jpg
#   inflating: Dataset/0/1397.jpg
#   inflating: __MACOSX/Dataset/0/._1397.jpg
#   inflating: Dataset/0/0089.jpg
#   inflating: __MACOSX/Dataset/0/._0089.jpg
#   inflating: Dataset/0/0937.jpg
#   inflating: __MACOSX/Dataset/0/._0937.jpg
#   inflating: Dataset/0/0923.jpg
#   inflating: __MACOSX/Dataset/0/._0923.jpg
#   inflating: Dataset/0/1383.jpg
#   inflating: __MACOSX/Dataset/0/._1383.jpg
#   inflating: Dataset/0/0076.jpg
#   inflating: __MACOSX/Dataset/0/._0076.jpg
#   inflating: Dataset/0/1368.jpg
#   inflating: __MACOSX/Dataset/0/._1368.jpg
#   inflating: Dataset/0/0710.jpg
#   inflating: __MACOSX/Dataset/0/._0710.jpg
#   inflating: Dataset/0/0704.jpg
#   inflating: __MACOSX/Dataset/0/._0704.jpg
#   inflating: Dataset/0/0062.jpg
#   inflating: __MACOSX/Dataset/0/._0062.jpg
#   inflating: Dataset/0/1354.jpg
#   inflating: __MACOSX/Dataset/0/._1354.jpg
#   inflating: Dataset/0/1432.jpg
#   inflating: __MACOSX/Dataset/0/._1432.jpg
#   inflating: Dataset/0/1426.jpg
#   inflating: __MACOSX/Dataset/0/._1426.jpg
#   inflating: Dataset/0/0738.jpg
#   inflating: __MACOSX/Dataset/0/._0738.jpg
#   inflating: Dataset/0/1340.jpg
#   inflating: __MACOSX/Dataset/0/._1340.jpg
#   inflating: Dataset/0/1430.jpg
#   inflating: __MACOSX/Dataset/0/._1430.jpg
#   inflating: Dataset/0/1356.jpg
#   inflating: __MACOSX/Dataset/0/._1356.jpg
#   inflating: Dataset/0/0048.jpg
#   inflating: __MACOSX/Dataset/0/._0048.jpg
#   inflating: Dataset/0/1342.jpg
#   inflating: __MACOSX/Dataset/0/._1342.jpg
#   inflating: Dataset/0/1424.jpg
#   inflating: __MACOSX/Dataset/0/._1424.jpg
#   inflating: Dataset/0/0712.jpg
#   inflating: __MACOSX/Dataset/0/._0712.jpg
#   inflating: Dataset/0/0074.jpg
#   inflating: __MACOSX/Dataset/0/._0074.jpg
#   inflating: Dataset/0/0060.jpg
#   inflating: __MACOSX/Dataset/0/._0060.jpg
#   inflating: Dataset/0/0706.jpg
#   inflating: __MACOSX/Dataset/0/._0706.jpg
#   inflating: Dataset/0/1418.jpg
#   inflating: __MACOSX/Dataset/0/._1418.jpg
#   inflating: Dataset/0/0935.jpg
#   inflating: __MACOSX/Dataset/0/._0935.jpg
#   inflating: Dataset/0/1395.jpg
#   inflating: __MACOSX/Dataset/0/._1395.jpg
#   inflating: Dataset/0/1381.jpg
#   inflating: __MACOSX/Dataset/0/._1381.jpg
#   inflating: Dataset/0/0921.jpg
#   inflating: __MACOSX/Dataset/0/._0921.jpg
#   inflating: Dataset/0/0909.jpg
#   inflating: __MACOSX/Dataset/0/._0909.jpg
#   inflating: Dataset/0/1154.jpg
#   inflating: __MACOSX/Dataset/0/._1154.jpg
#   inflating: Dataset/0/1632.jpg
#   inflating: __MACOSX/Dataset/0/._1632.jpg
#   inflating: Dataset/0/1626.jpg
#   inflating: __MACOSX/Dataset/0/._1626.jpg
#   inflating: Dataset/0/0538.jpg
#   inflating: __MACOSX/Dataset/0/._0538.jpg
#   inflating: Dataset/0/1140.jpg
#   inflating: __MACOSX/Dataset/0/._1140.jpg
#   inflating: Dataset/0/0276.jpg
#   inflating: __MACOSX/Dataset/0/._0276.jpg
#   inflating: Dataset/0/1168.jpg
#   inflating: __MACOSX/Dataset/0/._1168.jpg
#   inflating: Dataset/0/0510.jpg
#   inflating: __MACOSX/Dataset/0/._0510.jpg
#   inflating: Dataset/0/0504.jpg
#   inflating: __MACOSX/Dataset/0/._0504.jpg
#   inflating: Dataset/0/0262.jpg
#   inflating: __MACOSX/Dataset/0/._0262.jpg
#   inflating: Dataset/0/1197.jpg
#   inflating: __MACOSX/Dataset/0/._1197.jpg
#   inflating: Dataset/0/0289.jpg
#   inflating: __MACOSX/Dataset/0/._0289.jpg
#   inflating: Dataset/0/1829.jpg
#   inflating: __MACOSX/Dataset/0/._1829.jpg
#   inflating: Dataset/0/1183.jpg
#   inflating: __MACOSX/Dataset/0/._1183.jpg
#   inflating: Dataset/0/1815.jpg
#   inflating: __MACOSX/Dataset/0/._1815.jpg
#   inflating: Dataset/0/1801.jpg
#   inflating: __MACOSX/Dataset/0/._1801.jpg
#   inflating: Dataset/0/1020.jpg
#   inflating: __MACOSX/Dataset/0/._1020.jpg
#   inflating: Dataset/0/0458.jpg
#   inflating: __MACOSX/Dataset/0/._0458.jpg
#   inflating: Dataset/0/1746.jpg
#   inflating: __MACOSX/Dataset/0/._1746.jpg
#   inflating: Dataset/0/1752.jpg
#   inflating: __MACOSX/Dataset/0/._1752.jpg
#   inflating: Dataset/0/1034.jpg
#   inflating: __MACOSX/Dataset/0/._1034.jpg
#   inflating: Dataset/0/0302.jpg
#   inflating: __MACOSX/Dataset/0/._0302.jpg
#   inflating: Dataset/0/0464.jpg
#   inflating: __MACOSX/Dataset/0/._0464.jpg
#   inflating: Dataset/0/0470.jpg
#   inflating: __MACOSX/Dataset/0/._0470.jpg
#   inflating: Dataset/0/1008.jpg
#   inflating: __MACOSX/Dataset/0/._1008.jpg
#   inflating: Dataset/0/0316.jpg
#   inflating: __MACOSX/Dataset/0/._0316.jpg
#   inflating: Dataset/0/1785.jpg
#   inflating: __MACOSX/Dataset/0/._1785.jpg
#   inflating: Dataset/0/1791.jpg
#   inflating: __MACOSX/Dataset/0/._1791.jpg
#   inflating: Dataset/0/1544.jpg
#   inflating: __MACOSX/Dataset/0/._1544.jpg
#   inflating: Dataset/0/0882.jpg
#   inflating: __MACOSX/Dataset/0/._0882.jpg
#   inflating: Dataset/0/1222.jpg
#   inflating: __MACOSX/Dataset/0/._1222.jpg
#   inflating: Dataset/0/0128.jpg
#   inflating: __MACOSX/Dataset/0/._0128.jpg
#   inflating: Dataset/0/1236.jpg
#   inflating: __MACOSX/Dataset/0/._1236.jpg
#   inflating: Dataset/0/1550.jpg
#   inflating: __MACOSX/Dataset/0/._1550.jpg
#   inflating: Dataset/0/0896.jpg
#   inflating: __MACOSX/Dataset/0/._0896.jpg
#   inflating: Dataset/0/1578.jpg
#   inflating: __MACOSX/Dataset/0/._1578.jpg
#   inflating: Dataset/0/0666.jpg
#   inflating: __MACOSX/Dataset/0/._0666.jpg
#   inflating: Dataset/0/0100.jpg
#   inflating: __MACOSX/Dataset/0/._0100.jpg
#   inflating: Dataset/0/0114.jpg
#   inflating: __MACOSX/Dataset/0/._0114.jpg
#   inflating: Dataset/0/0672.jpg
#   inflating: __MACOSX/Dataset/0/._0672.jpg
#   inflating: Dataset/0/0699.jpg
#   inflating: __MACOSX/Dataset/0/._0699.jpg
#   inflating: Dataset/0/1587.jpg
#   inflating: __MACOSX/Dataset/0/._1587.jpg
#   inflating: Dataset/0/0841.jpg
#   inflating: __MACOSX/Dataset/0/._0841.jpg
#   inflating: Dataset/0/1593.jpg
#   inflating: __MACOSX/Dataset/0/._1593.jpg
#   inflating: Dataset/0/0855.jpg
#   inflating: __MACOSX/Dataset/0/._0855.jpg
#   inflating: Dataset/0/0869.jpg
#   inflating: __MACOSX/Dataset/0/._0869.jpg
#   inflating: Dataset/0/0868.jpg
#   inflating: __MACOSX/Dataset/0/._0868.jpg
#   inflating: Dataset/0/0854.jpg
#   inflating: __MACOSX/Dataset/0/._0854.jpg
#   inflating: Dataset/0/1592.jpg
#   inflating: __MACOSX/Dataset/0/._1592.jpg
#   inflating: Dataset/0/0840.jpg
#   inflating: __MACOSX/Dataset/0/._0840.jpg
#   inflating: Dataset/0/1586.jpg
#   inflating: __MACOSX/Dataset/0/._1586.jpg
#   inflating: Dataset/0/0698.jpg
#   inflating: __MACOSX/Dataset/0/._0698.jpg
#   inflating: Dataset/0/0115.jpg
#   inflating: __MACOSX/Dataset/0/._0115.jpg
#   inflating: Dataset/0/0673.jpg
#   inflating: __MACOSX/Dataset/0/._0673.jpg
#   inflating: Dataset/0/0667.jpg
#   inflating: __MACOSX/Dataset/0/._0667.jpg
#   inflating: Dataset/0/1579.jpg
#   inflating: __MACOSX/Dataset/0/._1579.jpg
#   inflating: Dataset/0/0101.jpg
#   inflating: __MACOSX/Dataset/0/._0101.jpg
#   inflating: Dataset/0/1237.jpg
#   inflating: __MACOSX/Dataset/0/._1237.jpg
#   inflating: Dataset/0/0129.jpg
#   inflating: __MACOSX/Dataset/0/._0129.jpg
#   inflating: Dataset/0/0897.jpg
#   inflating: __MACOSX/Dataset/0/._0897.jpg
#   inflating: Dataset/0/1551.jpg
#   inflating: __MACOSX/Dataset/0/._1551.jpg
#   inflating: Dataset/0/0883.jpg
#   inflating: __MACOSX/Dataset/0/._0883.jpg
#   inflating: Dataset/0/1545.jpg
#   inflating: __MACOSX/Dataset/0/._1545.jpg
#   inflating: Dataset/0/1223.jpg
#   inflating: __MACOSX/Dataset/0/._1223.jpg
#   inflating: Dataset/0/1790.jpg
#   inflating: __MACOSX/Dataset/0/._1790.jpg
#   inflating: Dataset/0/1784.jpg
#   inflating: __MACOSX/Dataset/0/._1784.jpg
#   inflating: Dataset/0/0471.jpg
#   inflating: __MACOSX/Dataset/0/._0471.jpg
#   inflating: Dataset/0/0317.jpg
#   inflating: __MACOSX/Dataset/0/._0317.jpg
#   inflating: Dataset/0/1009.jpg
#   inflating: __MACOSX/Dataset/0/._1009.jpg
#   inflating: Dataset/0/0303.jpg
#   inflating: __MACOSX/Dataset/0/._0303.jpg
#   inflating: Dataset/0/0465.jpg
#   inflating: __MACOSX/Dataset/0/._0465.jpg
#   inflating: Dataset/0/1753.jpg
#   inflating: __MACOSX/Dataset/0/._1753.jpg
#   inflating: Dataset/0/1035.jpg
#   inflating: __MACOSX/Dataset/0/._1035.jpg
#   inflating: Dataset/0/1021.jpg
#   inflating: __MACOSX/Dataset/0/._1021.jpg
#   inflating: Dataset/0/1747.jpg
#   inflating: __MACOSX/Dataset/0/._1747.jpg
#   inflating: Dataset/0/0459.jpg
#   inflating: __MACOSX/Dataset/0/._0459.jpg
#   inflating: Dataset/0/1800.jpg
#   inflating: __MACOSX/Dataset/0/._1800.jpg
#   inflating: Dataset/0/1814.jpg
#   inflating: __MACOSX/Dataset/0/._1814.jpg
#   inflating: Dataset/0/1182.jpg
#   inflating: __MACOSX/Dataset/0/._1182.jpg
#   inflating: Dataset/0/0288.jpg
#   inflating: __MACOSX/Dataset/0/._0288.jpg
#   inflating: Dataset/0/1196.jpg
#   inflating: __MACOSX/Dataset/0/._1196.jpg
#   inflating: Dataset/0/1828.jpg
#   inflating: __MACOSX/Dataset/0/._1828.jpg
#   inflating: Dataset/0/0505.jpg
#   inflating: __MACOSX/Dataset/0/._0505.jpg
#   inflating: Dataset/0/0263.jpg
#   inflating: __MACOSX/Dataset/0/._0263.jpg
#   inflating: Dataset/0/1169.jpg
#   inflating: __MACOSX/Dataset/0/._1169.jpg
#   inflating: Dataset/0/0277.jpg
#   inflating: __MACOSX/Dataset/0/._0277.jpg
#   inflating: Dataset/0/0511.jpg
#   inflating: __MACOSX/Dataset/0/._0511.jpg
#   inflating: Dataset/0/0539.jpg
#   inflating: __MACOSX/Dataset/0/._0539.jpg
#   inflating: Dataset/0/1627.jpg
#   inflating: __MACOSX/Dataset/0/._1627.jpg
#   inflating: Dataset/0/1141.jpg
#   inflating: __MACOSX/Dataset/0/._1141.jpg
#   inflating: Dataset/0/1155.jpg
#   inflating: __MACOSX/Dataset/0/._1155.jpg
#   inflating: Dataset/0/1633.jpg
#   inflating: __MACOSX/Dataset/0/._1633.jpg
#   inflating: Dataset/0/0908.jpg
#   inflating: __MACOSX/Dataset/0/._0908.jpg
#   inflating: Dataset/0/1380.jpg
#   inflating: __MACOSX/Dataset/0/._1380.jpg
#   inflating: Dataset/0/0920.jpg
#   inflating: __MACOSX/Dataset/0/._0920.jpg
#   inflating: Dataset/0/0934.jpg
#   inflating: __MACOSX/Dataset/0/._0934.jpg
#   inflating: Dataset/0/1394.jpg
#   inflating: __MACOSX/Dataset/0/._1394.jpg
#   inflating: Dataset/0/0061.jpg
#   inflating: __MACOSX/Dataset/0/._0061.jpg
#   inflating: Dataset/0/1419.jpg
#   inflating: __MACOSX/Dataset/0/._1419.jpg
#   inflating: Dataset/0/0707.jpg
#   inflating: __MACOSX/Dataset/0/._0707.jpg
#   inflating: Dataset/0/0713.jpg
#   inflating: __MACOSX/Dataset/0/._0713.jpg
#   inflating: Dataset/0/0075.jpg
#   inflating: __MACOSX/Dataset/0/._0075.jpg
#   inflating: Dataset/0/1343.jpg
#   inflating: __MACOSX/Dataset/0/._1343.jpg
#   inflating: Dataset/0/1425.jpg
#   inflating: __MACOSX/Dataset/0/._1425.jpg
#   inflating: Dataset/0/1431.jpg
#   inflating: __MACOSX/Dataset/0/._1431.jpg
#   inflating: Dataset/0/0049.jpg
#   inflating: __MACOSX/Dataset/0/._0049.jpg
#   inflating: Dataset/0/1357.jpg
#   inflating: __MACOSX/Dataset/0/._1357.jpg
#   inflating: Dataset/0/0774.jpg
#   inflating: __MACOSX/Dataset/0/._0774.jpg
#   inflating: Dataset/0/0012.jpg
#   inflating: __MACOSX/Dataset/0/._0012.jpg
#   inflating: Dataset/0/1318.jpg
#   inflating: __MACOSX/Dataset/0/._1318.jpg
#   inflating: Dataset/0/0006.jpg
#   inflating: __MACOSX/Dataset/0/._0006.jpg
#   inflating: Dataset/0/0760.jpg
#   inflating: __MACOSX/Dataset/0/._0760.jpg
#   inflating: Dataset/0/0748.jpg
#   inflating: __MACOSX/Dataset/0/._0748.jpg
#   inflating: Dataset/0/1456.jpg
#   inflating: __MACOSX/Dataset/0/._1456.jpg
#   inflating: Dataset/0/0990.jpg
#   inflating: __MACOSX/Dataset/0/._0990.jpg
#   inflating: Dataset/0/1330.jpg
#   inflating: __MACOSX/Dataset/0/._1330.jpg
#   inflating: Dataset/0/1324.jpg
#   inflating: __MACOSX/Dataset/0/._1324.jpg
#   inflating: Dataset/0/1442.jpg
#   inflating: __MACOSX/Dataset/0/._1442.jpg
#   inflating: Dataset/0/0984.jpg
#   inflating: __MACOSX/Dataset/0/._0984.jpg
#   inflating: Dataset/0/1495.jpg
#   inflating: __MACOSX/Dataset/0/._1495.jpg
#   inflating: Dataset/0/0953.jpg
#   inflating: __MACOSX/Dataset/0/._0953.jpg
#   inflating: Dataset/0/1481.jpg
#   inflating: __MACOSX/Dataset/0/._1481.jpg
#   inflating: Dataset/0/0947.jpg
#   inflating: __MACOSX/Dataset/0/._0947.jpg
#   inflating: Dataset/0/0210.jpg
#   inflating: __MACOSX/Dataset/0/._0210.jpg
#   inflating: Dataset/0/1668.jpg
#   inflating: __MACOSX/Dataset/0/._1668.jpg
#   inflating: Dataset/0/0576.jpg
#   inflating: __MACOSX/Dataset/0/._0576.jpg
#   inflating: Dataset/0/0562.jpg
#   inflating: __MACOSX/Dataset/0/._0562.jpg
#   inflating: Dataset/0/0204.jpg
#   inflating: __MACOSX/Dataset/0/._0204.jpg
#   inflating: Dataset/0/1132.jpg
#   inflating: __MACOSX/Dataset/0/._1132.jpg
#   inflating: Dataset/0/1654.jpg
#   inflating: __MACOSX/Dataset/0/._1654.jpg
#   inflating: Dataset/0/1640.jpg
#   inflating: __MACOSX/Dataset/0/._1640.jpg
#   inflating: Dataset/0/0238.jpg
#   inflating: __MACOSX/Dataset/0/._0238.jpg
#   inflating: Dataset/0/1126.jpg
#   inflating: __MACOSX/Dataset/0/._1126.jpg
#   inflating: Dataset/0/1873.jpg
#   inflating: __MACOSX/Dataset/0/._1873.jpg
#   inflating: Dataset/0/1867.jpg
#   inflating: __MACOSX/Dataset/0/._1867.jpg
#   inflating: Dataset/0/0589.jpg
#   inflating: __MACOSX/Dataset/0/._0589.jpg
#   inflating: Dataset/0/1697.jpg
#   inflating: __MACOSX/Dataset/0/._1697.jpg
#   inflating: Dataset/0/1683.jpg
#   inflating: __MACOSX/Dataset/0/._1683.jpg
#   inflating: Dataset/0/0364.jpg
#   inflating: __MACOSX/Dataset/0/._0364.jpg
#   inflating: Dataset/0/0402.jpg
#   inflating: __MACOSX/Dataset/0/._0402.jpg
#   inflating: Dataset/0/0416.jpg
#   inflating: __MACOSX/Dataset/0/._0416.jpg
#   inflating: Dataset/0/1708.jpg
#   inflating: __MACOSX/Dataset/0/._1708.jpg
#   inflating: Dataset/0/0370.jpg
#   inflating: __MACOSX/Dataset/0/._0370.jpg
#   inflating: Dataset/0/1046.jpg
#   inflating: __MACOSX/Dataset/0/._1046.jpg
#   inflating: Dataset/0/0358.jpg
#   inflating: __MACOSX/Dataset/0/._0358.jpg
#   inflating: Dataset/0/1720.jpg
#   inflating: __MACOSX/Dataset/0/._1720.jpg
#   inflating: Dataset/0/1734.jpg
#   inflating: __MACOSX/Dataset/0/._1734.jpg
#   inflating: Dataset/0/1052.jpg
#   inflating: __MACOSX/Dataset/0/._1052.jpg
#   inflating: Dataset/0/1085.jpg
#   inflating: __MACOSX/Dataset/0/._1085.jpg
#   inflating: Dataset/0/1091.jpg
#   inflating: __MACOSX/Dataset/0/._1091.jpg
#   inflating: Dataset/0/0600.jpg
#   inflating: __MACOSX/Dataset/0/._0600.jpg
#   inflating: Dataset/0/0166.jpg
#   inflating: __MACOSX/Dataset/0/._0166.jpg
#   inflating: Dataset/0/1278.jpg
#   inflating: __MACOSX/Dataset/0/._1278.jpg
#   inflating: Dataset/0/0172.jpg
#   inflating: __MACOSX/Dataset/0/._0172.jpg
#   inflating: Dataset/0/0614.jpg
#   inflating: __MACOSX/Dataset/0/._0614.jpg
#   inflating: Dataset/0/1522.jpg
#   inflating: __MACOSX/Dataset/0/._1522.jpg
#   inflating: Dataset/0/1244.jpg
#   inflating: __MACOSX/Dataset/0/._1244.jpg
#   inflating: Dataset/0/1250.jpg
#   inflating: __MACOSX/Dataset/0/._1250.jpg
#   inflating: Dataset/0/1536.jpg
#   inflating: __MACOSX/Dataset/0/._1536.jpg
#   inflating: Dataset/0/0628.jpg
#   inflating: __MACOSX/Dataset/0/._0628.jpg
#   inflating: Dataset/0/0827.jpg
#   inflating: __MACOSX/Dataset/0/._0827.jpg
#   inflating: Dataset/0/1287.jpg
#   inflating: __MACOSX/Dataset/0/._1287.jpg
#   inflating: Dataset/0/0199.jpg
#   inflating: __MACOSX/Dataset/0/._0199.jpg
#   inflating: Dataset/0/1293.jpg
#   inflating: __MACOSX/Dataset/0/._1293.jpg
#   inflating: Dataset/0/0833.jpg
#   inflating: __MACOSX/Dataset/0/._0833.jpg
#   inflating: Dataset/0/1292.jpg
#   inflating: __MACOSX/Dataset/0/._1292.jpg
#   inflating: Dataset/0/0832.jpg
#   inflating: __MACOSX/Dataset/0/._0832.jpg
#   inflating: Dataset/0/0826.jpg
#   inflating: __MACOSX/Dataset/0/._0826.jpg
#   inflating: Dataset/0/0198.jpg
#   inflating: __MACOSX/Dataset/0/._0198.jpg
#   inflating: Dataset/0/1286.jpg
#   inflating: __MACOSX/Dataset/0/._1286.jpg
#   inflating: Dataset/0/1251.jpg
#   inflating: __MACOSX/Dataset/0/._1251.jpg
#   inflating: Dataset/0/0629.jpg
#   inflating: __MACOSX/Dataset/0/._0629.jpg
#   inflating: Dataset/0/1537.jpg
#   inflating: __MACOSX/Dataset/0/._1537.jpg
#   inflating: Dataset/0/1523.jpg
#   inflating: __MACOSX/Dataset/0/._1523.jpg
#   inflating: Dataset/0/1245.jpg
#   inflating: __MACOSX/Dataset/0/._1245.jpg
#   inflating: Dataset/0/0173.jpg
#   inflating: __MACOSX/Dataset/0/._0173.jpg
#   inflating: Dataset/0/0615.jpg
#   inflating: __MACOSX/Dataset/0/._0615.jpg
#   inflating: Dataset/0/0601.jpg
#   inflating: __MACOSX/Dataset/0/._0601.jpg
#   inflating: Dataset/0/1279.jpg
#   inflating: __MACOSX/Dataset/0/._1279.jpg
#   inflating: Dataset/0/0167.jpg
#   inflating: __MACOSX/Dataset/0/._0167.jpg
#   inflating: Dataset/0/1090.jpg
#   inflating: __MACOSX/Dataset/0/._1090.jpg
#   inflating: Dataset/0/1084.jpg
#   inflating: __MACOSX/Dataset/0/._1084.jpg
#   inflating: Dataset/0/1735.jpg
#   inflating: __MACOSX/Dataset/0/._1735.jpg
#   inflating: Dataset/0/1053.jpg
#   inflating: __MACOSX/Dataset/0/._1053.jpg
#   inflating: Dataset/0/0359.jpg
#   inflating: __MACOSX/Dataset/0/._0359.jpg
#   inflating: Dataset/0/1047.jpg
#   inflating: __MACOSX/Dataset/0/._1047.jpg
#   inflating: Dataset/0/1721.jpg
#   inflating: __MACOSX/Dataset/0/._1721.jpg
#   inflating: Dataset/0/1709.jpg
#   inflating: __MACOSX/Dataset/0/._1709.jpg
#   inflating: Dataset/0/0417.jpg
#   inflating: __MACOSX/Dataset/0/._0417.jpg
#   inflating: Dataset/0/0371.jpg
#   inflating: __MACOSX/Dataset/0/._0371.jpg
#   inflating: Dataset/0/0365.jpg
#   inflating: __MACOSX/Dataset/0/._0365.jpg
#   inflating: Dataset/0/0403.jpg
#   inflating: __MACOSX/Dataset/0/._0403.jpg
#   inflating: Dataset/0/1682.jpg
#   inflating: __MACOSX/Dataset/0/._1682.jpg
#   inflating: Dataset/0/1696.jpg
#   inflating: __MACOSX/Dataset/0/._1696.jpg
#   inflating: Dataset/0/0588.jpg
#   inflating: __MACOSX/Dataset/0/._0588.jpg
#   inflating: Dataset/0/1866.jpg
#   inflating: __MACOSX/Dataset/0/._1866.jpg
#   inflating: Dataset/0/1872.jpg
#   inflating: __MACOSX/Dataset/0/._1872.jpg
#   inflating: Dataset/0/1641.jpg
#   inflating: __MACOSX/Dataset/0/._1641.jpg
#   inflating: Dataset/0/1127.jpg
#   inflating: __MACOSX/Dataset/0/._1127.jpg
#   inflating: Dataset/0/0239.jpg
#   inflating: __MACOSX/Dataset/0/._0239.jpg
#   inflating: Dataset/0/1133.jpg
#   inflating: __MACOSX/Dataset/0/._1133.jpg
#   inflating: Dataset/0/1655.jpg
#   inflating: __MACOSX/Dataset/0/._1655.jpg
#   inflating: Dataset/0/0563.jpg
#   inflating: __MACOSX/Dataset/0/._0563.jpg
#   inflating: Dataset/0/0205.jpg
#   inflating: __MACOSX/Dataset/0/._0205.jpg
#   inflating: Dataset/0/0211.jpg
#   inflating: __MACOSX/Dataset/0/._0211.jpg
#   inflating: Dataset/0/0577.jpg
#   inflating: __MACOSX/Dataset/0/._0577.jpg
#   inflating: Dataset/0/1669.jpg
#   inflating: __MACOSX/Dataset/0/._1669.jpg
#   inflating: Dataset/0/0946.jpg
#   inflating: __MACOSX/Dataset/0/._0946.jpg
#   inflating: Dataset/0/1480.jpg
#   inflating: __MACOSX/Dataset/0/._1480.jpg
#   inflating: Dataset/0/0952.jpg
#   inflating: __MACOSX/Dataset/0/._0952.jpg
#   inflating: Dataset/0/1494.jpg
#   inflating: __MACOSX/Dataset/0/._1494.jpg
#   inflating: Dataset/0/1325.jpg
#   inflating: __MACOSX/Dataset/0/._1325.jpg
#   inflating: Dataset/0/0985.jpg
#   inflating: __MACOSX/Dataset/0/._0985.jpg
#   inflating: Dataset/0/1443.jpg
#   inflating: __MACOSX/Dataset/0/._1443.jpg
#   inflating: Dataset/0/0991.jpg
#   inflating: __MACOSX/Dataset/0/._0991.jpg
#   inflating: Dataset/0/1457.jpg
#   inflating: __MACOSX/Dataset/0/._1457.jpg
#   inflating: Dataset/0/0749.jpg
#   inflating: __MACOSX/Dataset/0/._0749.jpg
#   inflating: Dataset/0/1331.jpg
#   inflating: __MACOSX/Dataset/0/._1331.jpg
#   inflating: Dataset/0/0007.jpg
#   inflating: __MACOSX/Dataset/0/._0007.jpg
#   inflating: Dataset/0/1319.jpg
#   inflating: __MACOSX/Dataset/0/._1319.jpg
#   inflating: Dataset/0/0761.jpg
#   inflating: __MACOSX/Dataset/0/._0761.jpg
#   inflating: Dataset/0/0775.jpg
#   inflating: __MACOSX/Dataset/0/._0775.jpg
#   inflating: Dataset/0/0013.jpg
#   inflating: __MACOSX/Dataset/0/._0013.jpg
#   inflating: Dataset/0/0763.jpg
#   inflating: __MACOSX/Dataset/0/._0763.jpg
#   inflating: Dataset/0/0005.jpg
#   inflating: __MACOSX/Dataset/0/._0005.jpg
#   inflating: Dataset/0/0011.jpg
#   inflating: __MACOSX/Dataset/0/._0011.jpg
#   inflating: Dataset/0/0777.jpg
#   inflating: __MACOSX/Dataset/0/._0777.jpg
#   inflating: Dataset/0/1469.jpg
#   inflating: __MACOSX/Dataset/0/._1469.jpg
#   inflating: Dataset/0/1441.jpg
#   inflating: __MACOSX/Dataset/0/._1441.jpg
#   inflating: Dataset/0/0987.jpg
#   inflating: __MACOSX/Dataset/0/._0987.jpg
#   inflating: Dataset/0/1327.jpg
#   inflating: __MACOSX/Dataset/0/._1327.jpg
#   inflating: Dataset/0/0039.jpg
#   inflating: __MACOSX/Dataset/0/._0039.jpg
#   inflating: Dataset/0/1333.jpg
#   inflating: __MACOSX/Dataset/0/._1333.jpg
#   inflating: Dataset/0/1455.jpg
#   inflating: __MACOSX/Dataset/0/._1455.jpg
#   inflating: Dataset/0/0993.jpg
#   inflating: __MACOSX/Dataset/0/._0993.jpg
#   inflating: Dataset/0/0978.jpg
#   inflating: __MACOSX/Dataset/0/._0978.jpg
#   inflating: Dataset/0/1482.jpg
#   inflating: __MACOSX/Dataset/0/._1482.jpg
#   inflating: Dataset/0/0944.jpg
#   inflating: __MACOSX/Dataset/0/._0944.jpg
#   inflating: Dataset/0/1496.jpg
#   inflating: __MACOSX/Dataset/0/._1496.jpg
#   inflating: Dataset/0/0950.jpg
#   inflating: __MACOSX/Dataset/0/._0950.jpg
#   inflating: Dataset/0/0788.jpg
#   inflating: __MACOSX/Dataset/0/._0788.jpg
#   inflating: Dataset/0/0207.jpg
#   inflating: __MACOSX/Dataset/0/._0207.jpg
#   inflating: Dataset/0/1119.jpg
#   inflating: __MACOSX/Dataset/0/._1119.jpg
#   inflating: Dataset/0/0561.jpg
#   inflating: __MACOSX/Dataset/0/._0561.jpg
#   inflating: Dataset/0/0575.jpg
#   inflating: __MACOSX/Dataset/0/._0575.jpg
#   inflating: Dataset/0/0213.jpg
#   inflating: __MACOSX/Dataset/0/._0213.jpg
#   inflating: Dataset/0/1125.jpg
#   inflating: __MACOSX/Dataset/0/._1125.jpg
#   inflating: Dataset/0/1643.jpg
#   inflating: __MACOSX/Dataset/0/._1643.jpg
#   inflating: Dataset/0/1657.jpg
#   inflating: __MACOSX/Dataset/0/._1657.jpg
#   inflating: Dataset/0/0549.jpg
#   inflating: __MACOSX/Dataset/0/._0549.jpg
#   inflating: Dataset/0/1131.jpg
#   inflating: __MACOSX/Dataset/0/._1131.jpg
#   inflating: Dataset/0/1864.jpg
#   inflating: __MACOSX/Dataset/0/._1864.jpg
#   inflating: Dataset/0/1870.jpg
#   inflating: __MACOSX/Dataset/0/._1870.jpg
#   inflating: Dataset/0/1858.jpg
#   inflating: __MACOSX/Dataset/0/._1858.jpg
#   inflating: Dataset/0/1680.jpg
#   inflating: __MACOSX/Dataset/0/._1680.jpg
#   inflating: Dataset/0/1694.jpg
#   inflating: __MACOSX/Dataset/0/._1694.jpg
#   inflating: Dataset/0/0373.jpg
#   inflating: __MACOSX/Dataset/0/._0373.jpg
#   inflating: Dataset/0/0415.jpg
#   inflating: __MACOSX/Dataset/0/._0415.jpg
#   inflating: Dataset/0/0401.jpg
#   inflating: __MACOSX/Dataset/0/._0401.jpg
#   inflating: Dataset/0/1079.jpg
#   inflating: __MACOSX/Dataset/0/._1079.jpg
#   inflating: Dataset/0/0367.jpg
#   inflating: __MACOSX/Dataset/0/._0367.jpg
#   inflating: Dataset/0/1051.jpg
#   inflating: __MACOSX/Dataset/0/._1051.jpg
#   inflating: Dataset/0/0429.jpg
#   inflating: __MACOSX/Dataset/0/._0429.jpg
#   inflating: Dataset/0/1737.jpg
#   inflating: __MACOSX/Dataset/0/._1737.jpg
#   inflating: Dataset/0/1723.jpg
#   inflating: __MACOSX/Dataset/0/._1723.jpg
#   inflating: Dataset/0/1045.jpg
#   inflating: __MACOSX/Dataset/0/._1045.jpg
#   inflating: Dataset/0/1092.jpg
#   inflating: __MACOSX/Dataset/0/._1092.jpg
#   inflating: Dataset/0/0398.jpg
#   inflating: __MACOSX/Dataset/0/._0398.jpg
#   inflating: Dataset/0/1086.jpg
#   inflating: __MACOSX/Dataset/0/._1086.jpg
#   inflating: Dataset/0/1509.jpg
#   inflating: __MACOSX/Dataset/0/._1509.jpg
#   inflating: Dataset/0/0617.jpg
#   inflating: __MACOSX/Dataset/0/._0617.jpg
#   inflating: Dataset/0/0171.jpg
#   inflating: __MACOSX/Dataset/0/._0171.jpg
#   inflating: Dataset/0/0165.jpg
#   inflating: __MACOSX/Dataset/0/._0165.jpg
#   inflating: Dataset/0/0603.jpg
#   inflating: __MACOSX/Dataset/0/._0603.jpg
#   inflating: Dataset/0/1535.jpg
#   inflating: __MACOSX/Dataset/0/._1535.jpg
#   inflating: Dataset/0/1253.jpg
#   inflating: __MACOSX/Dataset/0/._1253.jpg
#   inflating: Dataset/0/0159.jpg
#   inflating: __MACOSX/Dataset/0/._0159.jpg
#   inflating: Dataset/0/1247.jpg
#   inflating: __MACOSX/Dataset/0/._1247.jpg
#   inflating: Dataset/0/1521.jpg
#   inflating: __MACOSX/Dataset/0/._1521.jpg
#   inflating: Dataset/0/0818.jpg
#   inflating: __MACOSX/Dataset/0/._0818.jpg
#   inflating: Dataset/0/0830.jpg
#   inflating: __MACOSX/Dataset/0/._0830.jpg
#   inflating: Dataset/0/1290.jpg
#   inflating: __MACOSX/Dataset/0/._1290.jpg
#   inflating: Dataset/0/1284.jpg
#   inflating: __MACOSX/Dataset/0/._1284.jpg
#   inflating: Dataset/0/0824.jpg
#   inflating: __MACOSX/Dataset/0/._0824.jpg
#   inflating: Dataset/0/1285.jpg
#   inflating: __MACOSX/Dataset/0/._1285.jpg
#   inflating: Dataset/0/0825.jpg
#   inflating: __MACOSX/Dataset/0/._0825.jpg
#   inflating: Dataset/0/0831.jpg
#   inflating: __MACOSX/Dataset/0/._0831.jpg
#   inflating: Dataset/0/1291.jpg
#   inflating: __MACOSX/Dataset/0/._1291.jpg
#   inflating: Dataset/0/0819.jpg
#   inflating: __MACOSX/Dataset/0/._0819.jpg
#   inflating: Dataset/0/1246.jpg
#   inflating: __MACOSX/Dataset/0/._1246.jpg
#   inflating: Dataset/0/0158.jpg
#   inflating: __MACOSX/Dataset/0/._0158.jpg
#   inflating: Dataset/0/1520.jpg
#   inflating: __MACOSX/Dataset/0/._1520.jpg
#   inflating: Dataset/0/1534.jpg
#   inflating: __MACOSX/Dataset/0/._1534.jpg
#   inflating: Dataset/0/1252.jpg
#   inflating: __MACOSX/Dataset/0/._1252.jpg
#   inflating: Dataset/0/0164.jpg
#   inflating: __MACOSX/Dataset/0/._0164.jpg
#   inflating: Dataset/0/0602.jpg
#   inflating: __MACOSX/Dataset/0/._0602.jpg
#   inflating: Dataset/0/0616.jpg
#   inflating: __MACOSX/Dataset/0/._0616.jpg
#   inflating: Dataset/0/1508.jpg
#   inflating: __MACOSX/Dataset/0/._1508.jpg
#   inflating: Dataset/0/0170.jpg
#   inflating: __MACOSX/Dataset/0/._0170.jpg
#   inflating: Dataset/0/1087.jpg
#   inflating: __MACOSX/Dataset/0/._1087.jpg
#   inflating: Dataset/0/0399.jpg
#   inflating: __MACOSX/Dataset/0/._0399.jpg
#   inflating: Dataset/0/1093.jpg
#   inflating: __MACOSX/Dataset/0/._1093.jpg
#   inflating: Dataset/0/1722.jpg
#   inflating: __MACOSX/Dataset/0/._1722.jpg
#   inflating: Dataset/0/1044.jpg
#   inflating: __MACOSX/Dataset/0/._1044.jpg
#   inflating: Dataset/0/1050.jpg
#   inflating: __MACOSX/Dataset/0/._1050.jpg
#   inflating: Dataset/0/1736.jpg
#   inflating: __MACOSX/Dataset/0/._1736.jpg
#   inflating: Dataset/0/0428.jpg
#   inflating: __MACOSX/Dataset/0/._0428.jpg
#   inflating: Dataset/0/0400.jpg
#   inflating: __MACOSX/Dataset/0/._0400.jpg
#   inflating: Dataset/0/0366.jpg
#   inflating: __MACOSX/Dataset/0/._0366.jpg
#   inflating: Dataset/0/1078.jpg
#   inflating: __MACOSX/Dataset/0/._1078.jpg
#   inflating: Dataset/0/0372.jpg
#   inflating: __MACOSX/Dataset/0/._0372.jpg
#   inflating: Dataset/0/0414.jpg
#   inflating: __MACOSX/Dataset/0/._0414.jpg
#   inflating: Dataset/0/1695.jpg
#   inflating: __MACOSX/Dataset/0/._1695.jpg
#   inflating: Dataset/0/1681.jpg
#   inflating: __MACOSX/Dataset/0/._1681.jpg
#   inflating: Dataset/0/1859.jpg
#   inflating: __MACOSX/Dataset/0/._1859.jpg
#   inflating: Dataset/0/1871.jpg
#   inflating: __MACOSX/Dataset/0/._1871.jpg
#   inflating: Dataset/0/1865.jpg
#   inflating: __MACOSX/Dataset/0/._1865.jpg
#   inflating: Dataset/0/0548.jpg
#   inflating: __MACOSX/Dataset/0/._0548.jpg
#   inflating: Dataset/0/1656.jpg
#   inflating: __MACOSX/Dataset/0/._1656.jpg
#   inflating: Dataset/0/1130.jpg
#   inflating: __MACOSX/Dataset/0/._1130.jpg
#   inflating: Dataset/0/1124.jpg
#   inflating: __MACOSX/Dataset/0/._1124.jpg
#   inflating: Dataset/0/1642.jpg
#   inflating: __MACOSX/Dataset/0/._1642.jpg
#   inflating: Dataset/0/0574.jpg
#   inflating: __MACOSX/Dataset/0/._0574.jpg
#   inflating: Dataset/0/0212.jpg
#   inflating: __MACOSX/Dataset/0/._0212.jpg
#   inflating: Dataset/0/1118.jpg
#   inflating: __MACOSX/Dataset/0/._1118.jpg
#   inflating: Dataset/0/0206.jpg
#   inflating: __MACOSX/Dataset/0/._0206.jpg
#   inflating: Dataset/0/0560.jpg
#   inflating: __MACOSX/Dataset/0/._0560.jpg
#   inflating: Dataset/0/0789.jpg
#   inflating: __MACOSX/Dataset/0/._0789.jpg
#   inflating: Dataset/0/0951.jpg
#   inflating: __MACOSX/Dataset/0/._0951.jpg
#   inflating: Dataset/0/1497.jpg
#   inflating: __MACOSX/Dataset/0/._1497.jpg
#   inflating: Dataset/0/0945.jpg
#   inflating: __MACOSX/Dataset/0/._0945.jpg
#   inflating: Dataset/0/1483.jpg
#   inflating: __MACOSX/Dataset/0/._1483.jpg
#   inflating: Dataset/0/0979.jpg
#   inflating: __MACOSX/Dataset/0/._0979.jpg
#   inflating: Dataset/0/1332.jpg
#   inflating: __MACOSX/Dataset/0/._1332.jpg
#   inflating: Dataset/0/0992.jpg
#   inflating: __MACOSX/Dataset/0/._0992.jpg
#   inflating: Dataset/0/1454.jpg
#   inflating: __MACOSX/Dataset/0/._1454.jpg
#   inflating: Dataset/0/0986.jpg
#   inflating: __MACOSX/Dataset/0/._0986.jpg
#   inflating: Dataset/0/1440.jpg
#   inflating: __MACOSX/Dataset/0/._1440.jpg
#   inflating: Dataset/0/0038.jpg
#   inflating: __MACOSX/Dataset/0/._0038.jpg
#   inflating: Dataset/0/1326.jpg
#   inflating: __MACOSX/Dataset/0/._1326.jpg
#   inflating: Dataset/0/0010.jpg
#   inflating: __MACOSX/Dataset/0/._0010.jpg
#   inflating: Dataset/0/1468.jpg
#   inflating: __MACOSX/Dataset/0/._1468.jpg
#   inflating: Dataset/0/0776.jpg
#   inflating: __MACOSX/Dataset/0/._0776.jpg
#   inflating: Dataset/0/0762.jpg
#   inflating: __MACOSX/Dataset/0/._0762.jpg
#   inflating: Dataset/0/0004.jpg
#   inflating: __MACOSX/Dataset/0/._0004.jpg
#   inflating: Dataset/0/1322.jpg
#   inflating: __MACOSX/Dataset/0/._1322.jpg
#   inflating: Dataset/0/0982.jpg
#   inflating: __MACOSX/Dataset/0/._0982.jpg
#   inflating: Dataset/0/1444.jpg
#   inflating: __MACOSX/Dataset/0/._1444.jpg
#   inflating: Dataset/0/0996.jpg
#   inflating: __MACOSX/Dataset/0/._0996.jpg
#   inflating: Dataset/0/1450.jpg
#   inflating: __MACOSX/Dataset/0/._1450.jpg
#   inflating: Dataset/0/1336.jpg
#   inflating: __MACOSX/Dataset/0/._1336.jpg
#   inflating: Dataset/0/0028.jpg
#   inflating: __MACOSX/Dataset/0/._0028.jpg
#   inflating: Dataset/0/0766.jpg
#   inflating: __MACOSX/Dataset/0/._0766.jpg
#   inflating: Dataset/0/1478.jpg
#   inflating: __MACOSX/Dataset/0/._1478.jpg
#   inflating: Dataset/0/0772.jpg
#   inflating: __MACOSX/Dataset/0/._0772.jpg
#   inflating: Dataset/0/0014.jpg
#   inflating: __MACOSX/Dataset/0/._0014.jpg
#   inflating: Dataset/0/0941.jpg
#   inflating: __MACOSX/Dataset/0/._0941.jpg
#   inflating: Dataset/0/1487.jpg
#   inflating: __MACOSX/Dataset/0/._1487.jpg
#   inflating: Dataset/0/0799.jpg
#   inflating: __MACOSX/Dataset/0/._0799.jpg
#   inflating: Dataset/0/0955.jpg
#   inflating: __MACOSX/Dataset/0/._0955.jpg
#   inflating: Dataset/0/1493.jpg
#   inflating: __MACOSX/Dataset/0/._1493.jpg
#   inflating: Dataset/0/0969.jpg
#   inflating: __MACOSX/Dataset/0/._0969.jpg
#   inflating: Dataset/0/1646.jpg
#   inflating: __MACOSX/Dataset/0/._1646.jpg
#   inflating: Dataset/0/0558.jpg
#   inflating: __MACOSX/Dataset/0/._0558.jpg
#   inflating: Dataset/0/1120.jpg
#   inflating: __MACOSX/Dataset/0/._1120.jpg
#   inflating: Dataset/0/1134.jpg
#   inflating: __MACOSX/Dataset/0/._1134.jpg
#   inflating: Dataset/0/1652.jpg
#   inflating: __MACOSX/Dataset/0/._1652.jpg
#   inflating: Dataset/0/0564.jpg
#   inflating: __MACOSX/Dataset/0/._0564.jpg
#   inflating: Dataset/0/0202.jpg
#   inflating: __MACOSX/Dataset/0/._0202.jpg
#   inflating: Dataset/0/0216.jpg
#   inflating: __MACOSX/Dataset/0/._0216.jpg
#   inflating: Dataset/0/1108.jpg
#   inflating: __MACOSX/Dataset/0/._1108.jpg
#   inflating: Dataset/0/0570.jpg
#   inflating: __MACOSX/Dataset/0/._0570.jpg
#   inflating: Dataset/0/1685.jpg
#   inflating: __MACOSX/Dataset/0/._1685.jpg
#   inflating: Dataset/0/1849.jpg
#   inflating: __MACOSX/Dataset/0/._1849.jpg
#   inflating: Dataset/0/1691.jpg
#   inflating: __MACOSX/Dataset/0/._1691.jpg
#   inflating: Dataset/0/1861.jpg
#   inflating: __MACOSX/Dataset/0/._1861.jpg
#   inflating: Dataset/0/1875.jpg
#   inflating: __MACOSX/Dataset/0/._1875.jpg
#   inflating: Dataset/0/1732.jpg
#   inflating: __MACOSX/Dataset/0/._1732.jpg
#   inflating: Dataset/0/1054.jpg
#   inflating: __MACOSX/Dataset/0/._1054.jpg
#   inflating: Dataset/0/1040.jpg
#   inflating: __MACOSX/Dataset/0/._1040.jpg
#   inflating: Dataset/0/0438.jpg
#   inflating: __MACOSX/Dataset/0/._0438.jpg
#   inflating: Dataset/0/1726.jpg
#   inflating: __MACOSX/Dataset/0/._1726.jpg
#   inflating: Dataset/0/0410.jpg
#   inflating: __MACOSX/Dataset/0/._0410.jpg
#   inflating: Dataset/0/1068.jpg
#   inflating: __MACOSX/Dataset/0/._1068.jpg
#   inflating: Dataset/0/0376.jpg
#   inflating: __MACOSX/Dataset/0/._0376.jpg
#   inflating: Dataset/0/0362.jpg
#   inflating: __MACOSX/Dataset/0/._0362.jpg
#   inflating: Dataset/0/0404.jpg
#   inflating: __MACOSX/Dataset/0/._0404.jpg
#   inflating: Dataset/0/0389.jpg
#   inflating: __MACOSX/Dataset/0/._0389.jpg
#   inflating: Dataset/0/1097.jpg
#   inflating: __MACOSX/Dataset/0/._1097.jpg
#   inflating: Dataset/0/1083.jpg
#   inflating: __MACOSX/Dataset/0/._1083.jpg
#   inflating: Dataset/0/0148.jpg
#   inflating: __MACOSX/Dataset/0/._0148.jpg
#   inflating: Dataset/0/1256.jpg
#   inflating: __MACOSX/Dataset/0/._1256.jpg
#   inflating: Dataset/0/1530.jpg
#   inflating: __MACOSX/Dataset/0/._1530.jpg
#   inflating: Dataset/0/1524.jpg
#   inflating: __MACOSX/Dataset/0/._1524.jpg
#   inflating: Dataset/0/1242.jpg
#   inflating: __MACOSX/Dataset/0/._1242.jpg
#   inflating: Dataset/0/0174.jpg
#   inflating: __MACOSX/Dataset/0/._0174.jpg
#   inflating: Dataset/0/0612.jpg
#   inflating: __MACOSX/Dataset/0/._0612.jpg
#   inflating: Dataset/0/1518.jpg
#   inflating: __MACOSX/Dataset/0/._1518.jpg
#   inflating: Dataset/0/0606.jpg
#   inflating: __MACOSX/Dataset/0/._0606.jpg
#   inflating: Dataset/0/0160.jpg
#   inflating: __MACOSX/Dataset/0/._0160.jpg
#   inflating: Dataset/0/1295.jpg
#   inflating: __MACOSX/Dataset/0/._1295.jpg
#   inflating: Dataset/0/0835.jpg
#   inflating: __MACOSX/Dataset/0/._0835.jpg
#   inflating: Dataset/0/0821.jpg
#   inflating: __MACOSX/Dataset/0/._0821.jpg
#   inflating: Dataset/0/1281.jpg
#   inflating: __MACOSX/Dataset/0/._1281.jpg
#   inflating: Dataset/0/0809.jpg
#   inflating: __MACOSX/Dataset/0/._0809.jpg
#   inflating: Dataset/0/0808.jpg
#   inflating: __MACOSX/Dataset/0/._0808.jpg
#   inflating: Dataset/0/0820.jpg
#   inflating: __MACOSX/Dataset/0/._0820.jpg
#   inflating: Dataset/0/1280.jpg
#   inflating: __MACOSX/Dataset/0/._1280.jpg
#   inflating: Dataset/0/1294.jpg
#   inflating: __MACOSX/Dataset/0/._1294.jpg
#   inflating: Dataset/0/0834.jpg
#   inflating: __MACOSX/Dataset/0/._0834.jpg
#   inflating: Dataset/0/0607.jpg
#   inflating: __MACOSX/Dataset/0/._0607.jpg
#   inflating: Dataset/0/1519.jpg
#   inflating: __MACOSX/Dataset/0/._1519.jpg
#   inflating: Dataset/0/0161.jpg
#   inflating: __MACOSX/Dataset/0/._0161.jpg
#   inflating: Dataset/0/0175.jpg
#   inflating: __MACOSX/Dataset/0/._0175.jpg
#   inflating: Dataset/0/0613.jpg
#   inflating: __MACOSX/Dataset/0/._0613.jpg
#   inflating: Dataset/0/1525.jpg
#   inflating: __MACOSX/Dataset/0/._1525.jpg
#   inflating: Dataset/0/1243.jpg
#   inflating: __MACOSX/Dataset/0/._1243.jpg
#   inflating: Dataset/0/1257.jpg
#   inflating: __MACOSX/Dataset/0/._1257.jpg
#   inflating: Dataset/0/0149.jpg
#   inflating: __MACOSX/Dataset/0/._0149.jpg
#   inflating: Dataset/0/1531.jpg
#   inflating: __MACOSX/Dataset/0/._1531.jpg
#   inflating: Dataset/0/1082.jpg
#   inflating: __MACOSX/Dataset/0/._1082.jpg
#   inflating: Dataset/0/1096.jpg
#   inflating: __MACOSX/Dataset/0/._1096.jpg
#   inflating: Dataset/0/0388.jpg
#   inflating: __MACOSX/Dataset/0/._0388.jpg
#   inflating: Dataset/0/0363.jpg
#   inflating: __MACOSX/Dataset/0/._0363.jpg
#   inflating: Dataset/0/0405.jpg
#   inflating: __MACOSX/Dataset/0/._0405.jpg
#   inflating: Dataset/0/0411.jpg
#   inflating: __MACOSX/Dataset/0/._0411.jpg
#   inflating: Dataset/0/0377.jpg
#   inflating: __MACOSX/Dataset/0/._0377.jpg
#   inflating: Dataset/0/1069.jpg
#   inflating: __MACOSX/Dataset/0/._1069.jpg
#   inflating: Dataset/0/1041.jpg
#   inflating: __MACOSX/Dataset/0/._1041.jpg
#   inflating: Dataset/0/1727.jpg
#   inflating: __MACOSX/Dataset/0/._1727.jpg
#   inflating: Dataset/0/0439.jpg
#   inflating: __MACOSX/Dataset/0/._0439.jpg
#   inflating: Dataset/0/1733.jpg
#   inflating: __MACOSX/Dataset/0/._1733.jpg
#   inflating: Dataset/0/1055.jpg
#   inflating: __MACOSX/Dataset/0/._1055.jpg
#   inflating: Dataset/0/1874.jpg
#   inflating: __MACOSX/Dataset/0/._1874.jpg
#   inflating: Dataset/0/1860.jpg
#   inflating: __MACOSX/Dataset/0/._1860.jpg
#   inflating: Dataset/0/1690.jpg
# ...
#   inflating: __MACOSX/Dataset/2/._0432.jpg
#   inflating: Dataset/2/0383.jpg
#   inflating: __MACOSX/Dataset/2/._0383.jpg
#   inflating: Dataset/2/0397.jpg
#   inflating: __MACOSX/Dataset/2/._0397.jpg
#   inflating: Dataset/2/0142.jpg
#   inflating: __MACOSX/Dataset/2/._0142.jpg
#   inflating: Dataset/2/0156.jpg
#   inflating: __MACOSX/Dataset/2/._0156.jpg
#   inflating: Dataset/2/0181.jpg
#   inflating: __MACOSX/Dataset/2/._0181.jpg
#   inflating: Dataset/2/0195.jpg
#   inflating: __MACOSX/Dataset/2/._0195.jpg
#   inflating: Dataset/2/0194.jpg
#   inflating: __MACOSX/Dataset/2/._0194.jpg
#   inflating: Dataset/2/0180.jpg
#   inflating: __MACOSX/Dataset/2/._0180.jpg
#   inflating: Dataset/2/0157.jpg
#   inflating: __MACOSX/Dataset/2/._0157.jpg
#   inflating: Dataset/2/0143.jpg
#   inflating: __MACOSX/Dataset/2/._0143.jpg
#   inflating: Dataset/2/0396.jpg
#   inflating: __MACOSX/Dataset/2/._0396.jpg
#   inflating: Dataset/2/0382.jpg
#   inflating: __MACOSX/Dataset/2/._0382.jpg
#   inflating: Dataset/2/0355.jpg
#   inflating: __MACOSX/Dataset/2/._0355.jpg
#   inflating: Dataset/2/0433.jpg
#   inflating: __MACOSX/Dataset/2/._0433.jpg
#   inflating: Dataset/2/0427.jpg
#   inflating: __MACOSX/Dataset/2/._0427.jpg
#   inflating: Dataset/2/0341.jpg
#   inflating: __MACOSX/Dataset/2/._0341.jpg
#   inflating: Dataset/2/0369.jpg
#   inflating: __MACOSX/Dataset/2/._0369.jpg
#   inflating: Dataset/2/0221.jpg
#   inflating: __MACOSX/Dataset/2/._0221.jpg
#   inflating: Dataset/2/0547.jpg
#   inflating: __MACOSX/Dataset/2/._0547.jpg
#   inflating: Dataset/2/0553.jpg
#   inflating: __MACOSX/Dataset/2/._0553.jpg
#   inflating: Dataset/2/0235.jpg
#   inflating: __MACOSX/Dataset/2/._0235.jpg
#   inflating: Dataset/2/0209.jpg
#   inflating: __MACOSX/Dataset/2/._0209.jpg
#   inflating: Dataset/2/0023.jpg
#   inflating: __MACOSX/Dataset/2/._0023.jpg
#   inflating: Dataset/2/0037.jpg
#   inflating: __MACOSX/Dataset/2/._0037.jpg
#   inflating: Dataset/2/0050.jpg
#   inflating: __MACOSX/Dataset/2/._0050.jpg
#   inflating: Dataset/2/0044.jpg
#   inflating: __MACOSX/Dataset/2/._0044.jpg
#   inflating: Dataset/2/0078.jpg
#   inflating: __MACOSX/Dataset/2/._0078.jpg
#   inflating: Dataset/2/0093.jpg
#   inflating: __MACOSX/Dataset/2/._0093.jpg
#   inflating: Dataset/2/0087.jpg
#   inflating: __MACOSX/Dataset/2/._0087.jpg
#   inflating: Dataset/2/0534.jpg
#   inflating: __MACOSX/Dataset/2/._0534.jpg
#   inflating: Dataset/2/0252.jpg
#   inflating: __MACOSX/Dataset/2/._0252.jpg
#   inflating: Dataset/2/0246.jpg
#   inflating: __MACOSX/Dataset/2/._0246.jpg
#   inflating: Dataset/2/0520.jpg
#   inflating: __MACOSX/Dataset/2/._0520.jpg
#   inflating: Dataset/2/0508.jpg
#   inflating: __MACOSX/Dataset/2/._0508.jpg
#   inflating: Dataset/2/0291.jpg
#   inflating: __MACOSX/Dataset/2/._0291.jpg
#   inflating: Dataset/2/0285.jpg
#   inflating: __MACOSX/Dataset/2/._0285.jpg
#   inflating: Dataset/2/0440.jpg
#   inflating: __MACOSX/Dataset/2/._0440.jpg
#   inflating: Dataset/2/0326.jpg
#   inflating: __MACOSX/Dataset/2/._0326.jpg
#   inflating: Dataset/2/0332.jpg
#   inflating: __MACOSX/Dataset/2/._0332.jpg
#   inflating: Dataset/2/0454.jpg
#   inflating: __MACOSX/Dataset/2/._0454.jpg
#   inflating: Dataset/2/0468.jpg
#   inflating: __MACOSX/Dataset/2/._0468.jpg
#   inflating: Dataset/2/0483.jpg
#   inflating: __MACOSX/Dataset/2/._0483.jpg
#   inflating: Dataset/2/0497.jpg
#   inflating: __MACOSX/Dataset/2/._0497.jpg
#   inflating: Dataset/2/0124.jpg
#   inflating: __MACOSX/Dataset/2/._0124.jpg
#   inflating: Dataset/2/0130.jpg
#   inflating: __MACOSX/Dataset/2/._0130.jpg
#   inflating: Dataset/2/0118.jpg
#   inflating: __MACOSX/Dataset/2/._0118.jpg
#   inflating: Dataset/2/0119.jpg
#   inflating: __MACOSX/Dataset/2/._0119.jpg
#   inflating: Dataset/2/0131.jpg
#   inflating: __MACOSX/Dataset/2/._0131.jpg
#   inflating: Dataset/2/0125.jpg
#   inflating: __MACOSX/Dataset/2/._0125.jpg
#   inflating: Dataset/2/0496.jpg
#   inflating: __MACOSX/Dataset/2/._0496.jpg
#   inflating: Dataset/2/0482.jpg
#   inflating: __MACOSX/Dataset/2/._0482.jpg
#   inflating: Dataset/2/0469.jpg
#   inflating: __MACOSX/Dataset/2/._0469.jpg
#   inflating: Dataset/2/0333.jpg
#   inflating: __MACOSX/Dataset/2/._0333.jpg
#   inflating: Dataset/2/0455.jpg
#   inflating: __MACOSX/Dataset/2/._0455.jpg
#   inflating: Dataset/2/0441.jpg
#   inflating: __MACOSX/Dataset/2/._0441.jpg
#   inflating: Dataset/2/0327.jpg
#   inflating: __MACOSX/Dataset/2/._0327.jpg
#   inflating: Dataset/2/0284.jpg
#   inflating: __MACOSX/Dataset/2/._0284.jpg
#   inflating: Dataset/2/0290.jpg
#   inflating: __MACOSX/Dataset/2/._0290.jpg
#   inflating: Dataset/2/0509.jpg
#   inflating: __MACOSX/Dataset/2/._0509.jpg
#   inflating: Dataset/2/0247.jpg
#   inflating: __MACOSX/Dataset/2/._0247.jpg
#   inflating: Dataset/2/0521.jpg
#   inflating: __MACOSX/Dataset/2/._0521.jpg
#   inflating: Dataset/2/0535.jpg
#   inflating: __MACOSX/Dataset/2/._0535.jpg
#   inflating: Dataset/2/0253.jpg
#   inflating: __MACOSX/Dataset/2/._0253.jpg
#   inflating: Dataset/2/0086.jpg
#   inflating: __MACOSX/Dataset/2/._0086.jpg
#   inflating: Dataset/2/0092.jpg
#   inflating: __MACOSX/Dataset/2/._0092.jpg
#   inflating: Dataset/2/0079.jpg
#   inflating: __MACOSX/Dataset/2/._0079.jpg
#   inflating: Dataset/2/0045.jpg
#   inflating: __MACOSX/Dataset/2/._0045.jpg
#   inflating: Dataset/2/0051.jpg
#   inflating: __MACOSX/Dataset/2/._0051.jpg
#   inflating: Dataset/2/0047.jpg
#   inflating: __MACOSX/Dataset/2/._0047.jpg
#   inflating: Dataset/2/0053.jpg
#   inflating: __MACOSX/Dataset/2/._0053.jpg
#   inflating: Dataset/2/0084.jpg
#   inflating: __MACOSX/Dataset/2/._0084.jpg
#   inflating: Dataset/2/0090.jpg
#   inflating: __MACOSX/Dataset/2/._0090.jpg
#   inflating: Dataset/2/0523.jpg
#   inflating: __MACOSX/Dataset/2/._0523.jpg
#   inflating: Dataset/2/0245.jpg
#   inflating: __MACOSX/Dataset/2/._0245.jpg
#   inflating: Dataset/2/0251.jpg
#   inflating: __MACOSX/Dataset/2/._0251.jpg
#   inflating: Dataset/2/0537.jpg
#   inflating: __MACOSX/Dataset/2/._0537.jpg
#   inflating: Dataset/2/0279.jpg
#   inflating: __MACOSX/Dataset/2/._0279.jpg
#   inflating: Dataset/2/0286.jpg
#   inflating: __MACOSX/Dataset/2/._0286.jpg
#   inflating: Dataset/2/0292.jpg
#   inflating: __MACOSX/Dataset/2/._0292.jpg
#   inflating: Dataset/2/0457.jpg
#   inflating: __MACOSX/Dataset/2/._0457.jpg
#   inflating: Dataset/2/0331.jpg
#   inflating: __MACOSX/Dataset/2/._0331.jpg
#   inflating: Dataset/2/0325.jpg
#   inflating: __MACOSX/Dataset/2/._0325.jpg
#   inflating: Dataset/2/0443.jpg
#   inflating: __MACOSX/Dataset/2/._0443.jpg
#   inflating: Dataset/2/0319.jpg
#   inflating: __MACOSX/Dataset/2/._0319.jpg
#   inflating: Dataset/2/0494.jpg
#   inflating: __MACOSX/Dataset/2/._0494.jpg
#   inflating: Dataset/2/0480.jpg
#   inflating: __MACOSX/Dataset/2/._0480.jpg
#   inflating: Dataset/2/0133.jpg
#   inflating: __MACOSX/Dataset/2/._0133.jpg
#   inflating: Dataset/2/0127.jpg
#   inflating: __MACOSX/Dataset/2/._0127.jpg
#   inflating: Dataset/2/0126.jpg
#   inflating: __MACOSX/Dataset/2/._0126.jpg
#   inflating: Dataset/2/0132.jpg
#   inflating: __MACOSX/Dataset/2/._0132.jpg
#   inflating: Dataset/2/0481.jpg
#   inflating: __MACOSX/Dataset/2/._0481.jpg
#   inflating: Dataset/2/0495.jpg
#   inflating: __MACOSX/Dataset/2/._0495.jpg
#   inflating: Dataset/2/0318.jpg
#   inflating: __MACOSX/Dataset/2/._0318.jpg
#   inflating: Dataset/2/0324.jpg
#   inflating: __MACOSX/Dataset/2/._0324.jpg
#   inflating: Dataset/2/0442.jpg
#   inflating: __MACOSX/Dataset/2/._0442.jpg
#   inflating: Dataset/2/0456.jpg
#   inflating: __MACOSX/Dataset/2/._0456.jpg
#   inflating: Dataset/2/0330.jpg
#   inflating: __MACOSX/Dataset/2/._0330.jpg
#   inflating: Dataset/2/0293.jpg
#   inflating: __MACOSX/Dataset/2/._0293.jpg
#   inflating: Dataset/2/0287.jpg
#   inflating: __MACOSX/Dataset/2/._0287.jpg
#   inflating: Dataset/2/0278.jpg
#   inflating: __MACOSX/Dataset/2/._0278.jpg
#   inflating: Dataset/2/0250.jpg
#   inflating: __MACOSX/Dataset/2/._0250.jpg
#   inflating: Dataset/2/0536.jpg
#   inflating: __MACOSX/Dataset/2/._0536.jpg
#   inflating: Dataset/2/0522.jpg
#   inflating: __MACOSX/Dataset/2/._0522.jpg
#   inflating: Dataset/2/0244.jpg
#   inflating: __MACOSX/Dataset/2/._0244.jpg
#   inflating: Dataset/2/0091.jpg
#   inflating: __MACOSX/Dataset/2/._0091.jpg
#   inflating: Dataset/2/0085.jpg
#   inflating: __MACOSX/Dataset/2/._0085.jpg
#   inflating: Dataset/2/0052.jpg
#   inflating: __MACOSX/Dataset/2/._0052.jpg
#   inflating: Dataset/2/0046.jpg
#   inflating: __MACOSX/Dataset/2/._0046.jpg
#   inflating: Dataset/2/0042.jpg
#   inflating: __MACOSX/Dataset/2/._0042.jpg
#   inflating: Dataset/2/0056.jpg
#   inflating: __MACOSX/Dataset/2/._0056.jpg
#   inflating: Dataset/2/0081.jpg
#   inflating: __MACOSX/Dataset/2/._0081.jpg
#   inflating: Dataset/2/0095.jpg
#   inflating: __MACOSX/Dataset/2/._0095.jpg
#   inflating: Dataset/2/0268.jpg
#   inflating: __MACOSX/Dataset/2/._0268.jpg
#   inflating: Dataset/2/0240.jpg
#   inflating: __MACOSX/Dataset/2/._0240.jpg
#   inflating: Dataset/2/0526.jpg
#   inflating: __MACOSX/Dataset/2/._0526.jpg
#   inflating: Dataset/2/0532.jpg
#   inflating: __MACOSX/Dataset/2/._0532.jpg
#   inflating: Dataset/2/0254.jpg
#   inflating: __MACOSX/Dataset/2/._0254.jpg
#   inflating: Dataset/2/0283.jpg
#   inflating: __MACOSX/Dataset/2/._0283.jpg
#   inflating: Dataset/2/0297.jpg
#   inflating: __MACOSX/Dataset/2/._0297.jpg
#   inflating: Dataset/2/0308.jpg
#   inflating: __MACOSX/Dataset/2/._0308.jpg
#   inflating: Dataset/2/0334.jpg
#   inflating: __MACOSX/Dataset/2/._0334.jpg
#   inflating: Dataset/2/0452.jpg
#   inflating: __MACOSX/Dataset/2/._0452.jpg
#   inflating: Dataset/2/0446.jpg
#   inflating: __MACOSX/Dataset/2/._0446.jpg
#   inflating: Dataset/2/0320.jpg
#   inflating: __MACOSX/Dataset/2/._0320.jpg
#   inflating: Dataset/2/0491.jpg
#   inflating: __MACOSX/Dataset/2/._0491.jpg
#   inflating: Dataset/2/0485.jpg
#   inflating: __MACOSX/Dataset/2/._0485.jpg
#   inflating: Dataset/2/0136.jpg
#   inflating: __MACOSX/Dataset/2/._0136.jpg
#   inflating: Dataset/2/0122.jpg
#   inflating: __MACOSX/Dataset/2/._0122.jpg
#   inflating: Dataset/2/0123.jpg
#   inflating: __MACOSX/Dataset/2/._0123.jpg
#   inflating: Dataset/2/0137.jpg
#   inflating: __MACOSX/Dataset/2/._0137.jpg
#   inflating: Dataset/2/0484.jpg
#   inflating: __MACOSX/Dataset/2/._0484.jpg
#   inflating: Dataset/2/0490.jpg
#   inflating: __MACOSX/Dataset/2/._0490.jpg
#   inflating: Dataset/2/0447.jpg
#   inflating: __MACOSX/Dataset/2/._0447.jpg
#   inflating: Dataset/2/0321.jpg
#   inflating: __MACOSX/Dataset/2/._0321.jpg
#   inflating: Dataset/2/0335.jpg
#   inflating: __MACOSX/Dataset/2/._0335.jpg
#   inflating: Dataset/2/0453.jpg
#   inflating: __MACOSX/Dataset/2/._0453.jpg
#   inflating: Dataset/2/0309.jpg
#   inflating: __MACOSX/Dataset/2/._0309.jpg
#   inflating: Dataset/2/0296.jpg
#   inflating: __MACOSX/Dataset/2/._0296.jpg
#   inflating: Dataset/2/0282.jpg
#   inflating: __MACOSX/Dataset/2/._0282.jpg
#   inflating: Dataset/2/0533.jpg
#   inflating: __MACOSX/Dataset/2/._0533.jpg
#   inflating: Dataset/2/0255.jpg
#   inflating: __MACOSX/Dataset/2/._0255.jpg
#   inflating: Dataset/2/0241.jpg
#   inflating: __MACOSX/Dataset/2/._0241.jpg
#   inflating: Dataset/2/0527.jpg
#   inflating: __MACOSX/Dataset/2/._0527.jpg
#   inflating: Dataset/2/0269.jpg
#   inflating: __MACOSX/Dataset/2/._0269.jpg
#   inflating: Dataset/2/0094.jpg
#   inflating: __MACOSX/Dataset/2/._0094.jpg
#   inflating: Dataset/2/0080.jpg
#   inflating: __MACOSX/Dataset/2/._0080.jpg
#   inflating: Dataset/2/0057.jpg
#   inflating: __MACOSX/Dataset/2/._0057.jpg
#   inflating: Dataset/2/0043.jpg
#   inflating: __MACOSX/Dataset/2/._0043.jpg
#   inflating: Dataset/2/0069.jpg
#   inflating: __MACOSX/Dataset/2/._0069.jpg
#   inflating: Dataset/2/0055.jpg
#   inflating: __MACOSX/Dataset/2/._0055.jpg
#   inflating: Dataset/2/0041.jpg
#   inflating: __MACOSX/Dataset/2/._0041.jpg
#   inflating: Dataset/2/0096.jpg
#   inflating: __MACOSX/Dataset/2/._0096.jpg
#   inflating: Dataset/2/0082.jpg
#   inflating: __MACOSX/Dataset/2/._0082.jpg
#   inflating: Dataset/2/0519.jpg
#   inflating: __MACOSX/Dataset/2/._0519.jpg
#   inflating: Dataset/2/0257.jpg
#   inflating: __MACOSX/Dataset/2/._0257.jpg
#   inflating: Dataset/2/0531.jpg
#   inflating: __MACOSX/Dataset/2/._0531.jpg
#   inflating: Dataset/2/0525.jpg
#   inflating: __MACOSX/Dataset/2/._0525.jpg
#   inflating: Dataset/2/0243.jpg
#   inflating: __MACOSX/Dataset/2/._0243.jpg
#   inflating: Dataset/2/0294.jpg
#   inflating: __MACOSX/Dataset/2/._0294.jpg
#   inflating: Dataset/2/0280.jpg
#   inflating: __MACOSX/Dataset/2/._0280.jpg
#   inflating: Dataset/2/0479.jpg
#   inflating: __MACOSX/Dataset/2/._0479.jpg
#   inflating: Dataset/2/0323.jpg
#   inflating: __MACOSX/Dataset/2/._0323.jpg
#   inflating: Dataset/2/0445.jpg
#   inflating: __MACOSX/Dataset/2/._0445.jpg
#   inflating: Dataset/2/0451.jpg
#   inflating: __MACOSX/Dataset/2/._0451.jpg
#   inflating: Dataset/2/0337.jpg
#   inflating: __MACOSX/Dataset/2/._0337.jpg
#   inflating: Dataset/2/0486.jpg
#   inflating: __MACOSX/Dataset/2/._0486.jpg
#   inflating: Dataset/2/0492.jpg
#   inflating: __MACOSX/Dataset/2/._0492.jpg
#   inflating: Dataset/2/0109.jpg
#   inflating: __MACOSX/Dataset/2/._0109.jpg
#   inflating: Dataset/2/0121.jpg
#   inflating: __MACOSX/Dataset/2/._0121.jpg
#   inflating: Dataset/2/0135.jpg
#   inflating: __MACOSX/Dataset/2/._0135.jpg
#   inflating: Dataset/2/0134.jpg
#   inflating: __MACOSX/Dataset/2/._0134.jpg
#   inflating: Dataset/2/0120.jpg
#   inflating: __MACOSX/Dataset/2/._0120.jpg
#   inflating: Dataset/2/0108.jpg
#   inflating: __MACOSX/Dataset/2/._0108.jpg
#   inflating: Dataset/2/0493.jpg
#   inflating: __MACOSX/Dataset/2/._0493.jpg
#   inflating: Dataset/2/0487.jpg
#   inflating: __MACOSX/Dataset/2/._0487.jpg
#   inflating: Dataset/2/0450.jpg
#   inflating: __MACOSX/Dataset/2/._0450.jpg
#   inflating: Dataset/2/0336.jpg
#   inflating: __MACOSX/Dataset/2/._0336.jpg
#   inflating: Dataset/2/0322.jpg
#   inflating: __MACOSX/Dataset/2/._0322.jpg
#   inflating: Dataset/2/0444.jpg
#   inflating: __MACOSX/Dataset/2/._0444.jpg
#   inflating: Dataset/2/0478.jpg
#   inflating: __MACOSX/Dataset/2/._0478.jpg
#   inflating: Dataset/2/0281.jpg
#   inflating: __MACOSX/Dataset/2/._0281.jpg
#   inflating: Dataset/2/0295.jpg
#   inflating: __MACOSX/Dataset/2/._0295.jpg
#   inflating: Dataset/2/0524.jpg
#   inflating: __MACOSX/Dataset/2/._0524.jpg
#   inflating: Dataset/2/0242.jpg
#   inflating: __MACOSX/Dataset/2/._0242.jpg
#   inflating: Dataset/2/0256.jpg
#   inflating: __MACOSX/Dataset/2/._0256.jpg
#   inflating: Dataset/2/0530.jpg
#   inflating: __MACOSX/Dataset/2/._0530.jpg
#   inflating: Dataset/2/0518.jpg
#   inflating: __MACOSX/Dataset/2/._0518.jpg
#   inflating: Dataset/2/0083.jpg
#   inflating: __MACOSX/Dataset/2/._0083.jpg
#   inflating: Dataset/2/0097.jpg
#   inflating: __MACOSX/Dataset/2/._0097.jpg
#   inflating: Dataset/2/0040.jpg
#   inflating: __MACOSX/Dataset/2/._0040.jpg
#   inflating: Dataset/2/0054.jpg
#   inflating: __MACOSX/Dataset/2/._0054.jpg
#   inflating: Dataset/2/0068.jpg
#   inflating: __MACOSX/Dataset/2/._0068.jpg

# %% [markdown]
# ## 4 - Visualizing Data ##
#
# In this section, some of the images from each class are randomly displayed:

# %%
def show_samples():
  # The name of all images in current directory.
  sample_names = [name for name in os.listdir('.') if os.path.isfile(name)]

  # Choose 3 random images from current directory.
  rand_3 = np.random.randint(0, len(sample_names), 3)

  # Read and resize random images.
  sample_images = [cv2.resize(cv2.imread(file_name), (IMG_WIDTH, IMG_HEIGHT)) for file_name in [sample_names[i] for i in rand_3]]

  num_cols = 3     # Number of columns in plot.
  # Create desired plot.
  f, ax = plt.subplots(1, num_cols, figsize=(12,5),
                      gridspec_kw={'wspace':0.03, 'hspace':0.01}, 
                      squeeze=True)

  # Fill the plot with random images.
  for c in range(num_cols):
      ax[c].axis("off")
      ax[c].imshow(sample_images[c])
  plt.show()
  plt.close()

# %cd /content/Dataset/0
show_samples()                 # Plot random images from set 0.
# %cd ../1
show_samples()                 # Plot random images from set 1.
# %cd ../2
show_samples()                 # Plot random images from set 2.
# Out:
# /content/Dataset/0
# /content/Dataset/1
# /content/Dataset/2

# %% [markdown]
# ## 5 - Image Pre-Processing ##
#
# In this section, the necessary operations are performed before the training process:
#
# First of all, we find the region of intrests (ROI) of image:

# %%
def find_ROI(img):
    # Change the type of image to uint8 for further operations.
    img = img.astype(np.uint8)

    # Convert the RGB image to gray scale image.
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Blur the image with Gaussian filter.
    blurred_image = cv2.GaussianBlur(gray, (5, 5), 0)

    # A bilateral filter is a non-linear, edge-preserving, and noise-reducing smoothing filter for images.
    bilateral_image = cv2.bilateralFilter(blurred_image, 13, 15, 15)

    # Apply adaptive threshold to image to obtain a binary image.
    adther = cv2.adaptiveThreshold(bilateral_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 21, 2)

    # Find edges of image by Canny technique.
    canny = cv2.Canny(adther, 10, 240)

    # Thicken the lines found.
    lines = cv2.HoughLinesP(canny, 1, np.pi/180, 1)
    for line in lines:
        x1, y1, x2, y2 = line[0]
        cv2.line(canny, (x1, y1), (x2, y2), (255, 255, 255), 3)

    # Apply openning operation with long vertical line.
    #       ---> Only long vertical lines remain in image.
    openningV = cv2.morphologyEx(canny.copy(), cv2.MORPH_OPEN, STRUCTURING_ELEMENT_1)

    # Padding the image with black color.
    openningV = cv2.copyMakeBorder(openningV, 200, 200, 200, 200, cv2.BORDER_CONSTANT, 0)

    # Apply closing operation with long horizontal line.
    #       ---> Connect number plate components to each other.
    closeH = cv2.morphologyEx(openningV, cv2.MORPH_CLOSE, STRUCTURING_ELEMENT_2)

    # Apply openning operation with long horizontal line.
    #       ---> Remove non number plate components.
    openH = cv2.morphologyEx(closeH, cv2.MORPH_OPEN, STRUCTURING_ELEMENT_3)

    # Apply dilate operation with square element.
    #       ---> Connect number plate components to each other again.
    dilate = cv2.dilate(openH, STRUCTURING_ELEMENT_4)

    # Apply closing operation with long horizontal line.
    #       ---> Connect number plate components to each other in the case of...
    #            letter not be recognized.
    closeHAgain = cv2.morphologyEx(dilate, cv2.MORPH_CLOSE, STRUCTURING_ELEMENT_5)

    # Remove padding.
    closeHAgain = closeHAgain[200:-200, 200:-200]
    
    return closeHAgain

# %% [markdown]
# Then we mask original image with ROI image to obtain number plate.

# %%
def find_condidate_number_plate(img):
    # Resize the image.
    img = cv2.resize(img, (IMG_WIDTH, IMG_HEIGHT))

    # Find region of interest (ROI) of image.
    ROIs = find_ROI(img)

    # Mask the original image with ROI image.
    number_plate = cv2.bitwise_and(img, img, mask=ROIs)
    return number_plate

# %% [markdown]
# Finally, we gather two above functions as following function:

# %%
def my_preprocessing_function(img):
    # Find condidate number plate.
    new_image = find_condidate_number_plate(img)

    # Change the type of image to float32 for further operations.
    new_image = new_image.astype(np.float32)
    
    # Perform InceptionResnetV2 pre-process before training.
    final_image = preprocess_input(new_image)

    return final_image

# %% [markdown]
# ## 6 - Importing and Augmenting Data ##
#
# In this section, we we import and augment data from dataset folder by following functions:

# %%
# Split and augment data with following properties.
train_datagen_aug = ImageDataGenerator(rotation_range=20, shear_range=0.1, zoom_range=0.1,
                                       horizontal_flip=True,
                                       preprocessing_function=my_preprocessing_function,
                                       validation_split=0.2)

# %%
# Import training data.
train_generator_aug = train_datagen_aug.flow_from_directory('/content/Dataset', target_size=(IMG_HEIGHT, IMG_WIDTH), batch_size=BATCH_SIZE, shuffle=True, subset='training')

# Import validation data.
validation_generator_aug = train_datagen_aug.flow_from_directory('/content/Dataset', target_size=(IMG_HEIGHT, IMG_WIDTH), batch_size=BATCH_SIZE, shuffle=True, subset='validation')
# Out:
# Found 2183 images belonging to 3 classes.
# Found 544 images belonging to 3 classes.

# %% [markdown]
# ## 7 - Loading Model ##
#
# In this section, we load our modified model for this task.

# %%
from google.colab import drive

# Mount drive.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change directory to desire location.
# %cd /content/gdrive/MyDrive/ComputerVision/FinalProject/Final/NoShift
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/ComputerVision/FinalProject/Final/NoShift'
# /content/Dataset/2

# %%
# Load model.
model = load_model('/content/drive/MyDrive/InceptionResNetV2_20.h5')

# %% [markdown]
# ## 8 - Predicting Image ##
#
# In this section, we predict class of chosen image from dataset.

# %%
def predict(address):
    # Read image from address.
    img = cv2.imread(address)

    # Apply pre-processing on raw image.
    fianl_image = my_preprocessing_function(img)

    # Expand the dimension of final image for predict function.
    fianl_image = np.expand_dims(fianl_image, axis=0)

    # Find the index of maximum element.
    return np.argmax(model.predict(fianl_image))

# %%
# Predict an arbitrary image from class 1.
predict('Dataset/1/0016.jpg')

# %%
# Predict an arbitrary image from class 2.
predict('Dataset/2/0016.jpg')

# %%
# Predict an arbitrary image from class 0.
predict('Dataset/0/0016.jpg')

# %%
def test(address):
    # Open dataset file.
    dataset_file = open(address, 'r')

    # Read each line in dataset file.
    lines = dataset_file.readlines()

    # Remove '\n' from each element.
    lines = [line.strip() for line in lines]

    # Predict each image and modify corresponding line.
    lines = [line + ', ' + str(predict(line)) for line in lines]

    # Open predictions file.
    predictions_file = open('predictions.txt','w')

    # Convert list of lines to a string.
    text = '\n'.join(lines)

    # Write above string in the predictions file.
    predictions_file.write(text)

    # Close dataset file.
    dataset_file.close()

    # Close predictions file.
    predictions_file.close()

# %%
cp /content/drive/MyDrive/FCV99/dataset.txt dataset.txt

# %%
# %%time
# Predict dataset file images and create predictions file.
test('dataset.txt')
# Out:
# CPU times: user 2min 24s, sys: 20.6 s, total: 2min 45s
# Wall time: 5min 7s

# %%
import numpy as np
from sklearn.metrics import classification_report
y_true = np.loadtxt('/content/drive/MyDrive/FCV99/labels.txt')

# %%
y_pred = np.loadtxt('predictions.txt', usecols=1)
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.98      0.94       470
#          1.0       0.89      0.67      0.76        72
#          2.0       0.91      0.76      0.83       141
#
#     accuracy                           0.90       683
#    macro avg       0.90      0.80      0.84       683
# weighted avg       0.90      0.90      0.90       683
